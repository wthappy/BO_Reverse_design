# %%
# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np
import random
import torch

seed = 42
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    
# No warnings about setting value on copy of slice
pd.options.mode.chained_assignment = None

# Display up to 60 columns of a dataframe
pd.set_option('display.max_columns', 60)

# Matplotlib visualization
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline

# Internal ipython tool for setting figure size
from IPython.core.pylabtools import figsize

# Seaborn for visualization
import seaborn as sns

# Splitting data into training and testing
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # data

# %%
data = pd.read_csv('data.csv', encoding='gbk', low_memory=False)
data
# Out:
#      Cell_architecture Substrate_stack_sequence ETL_stack_sequence  \
# 0                  nip                SLG | FTO   TiO2-c | TiO2-nw
# 1                  nip                SLG | FTO   TiO2-c | TiO2-nw
# 2                  nip                SLG | FTO   TiO2-c | TiO2-nw
# 3                  nip                SLG | FTO             TiO2-c
# 4                  nip                SLG | FTO   TiO2-c | TiO2-mp
# ...                ...                      ...                ...
# 3520               nip                SLG | FTO   TiO2-c | TiO2-mp
# 3521               nip                SLG | FTO   TiO2-c | TiO2-mp
# 3522               nip                SLG | FTO   TiO2-c | TiO2-mp
# 3523               nip                SLG | ITO   TiO2-c | TiO2-mp
# 3524               nip                SLG | FTO             TiO2-c
#
#      ETL_additives_compounds      ETL_deposition_procedure  \
# 0                    Undoped            CBD | Hydrothermal
# 1                         Er            CBD | Hydrothermal
# 2                     Er; Yb            CBD | Hydrothermal
# 3                    Undoped                  Spin-coating
# 4                      TiCl4   Spin-coating | Spin-coating
# ...                      ...                           ...
# 3520                 Li-TFSI  Spray-pyrolys | Spin-coating
# 3521                 Li-TFSI  Spray-pyrolys | Spin-coating
# 3522                     In    Spin-coating | Spin-coating
# 3523                     In    Spin-coating | Spin-coating
# 3524                 Undoped                  Spin-coating
#
#       Perovskite_composition_perovskite_ABC3_structure  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ...                                                ...
# 3520                                                 1
# 3521                                                 1
# 3522                                                 1
# 3523                                                 1
# 3524                                                 1
#
#      Perovskite_composition_none_stoichiometry_components_in_excess  \
# 0                                                  none
# 1                                                  none
# 2                                                  none
# 3                                                  none
# 4                                                    MA
# ...                                                 ...
# 3520                                               none
# 3521                                               none
# 3522                                               none
# 3523                                               none
# 3524                                               none
#
#      Perovskite_additives_compounds Perovskite_deposition_procedure  DMF_DMSO  \
# 0                                Cl                    Spin-coating     1.000
# 1                                Cl                    Spin-coating     1.000
# 2                                Cl                    Spin-coating     1.000
# 3                                Cl                    Spin-coating     1.000
# 4                           Undoped                    Spin-coating     1.000
# ...                             ...                             ...       ...
# 3520                             Az                   Spray-coating     1.000
# 3521                             Az                    Spin-coating     1.000
# 3522                        Undoped                    Spin-coating     0.800
# 3523                        Undoped                    Spin-coating     0.800
# 3524                        Undoped    Spin-coating >> Spin-coating     0.625
#
#      Perovskite_deposition_quenching_media  \
# 0                                  Undoped
# 1                                  Undoped
# 2                                  Undoped
# 3                                  Undoped
# 4                                  Undoped
# ...                                    ...
# 3520                               Undoped
# 3521                               Undoped
# 3522                         Chlorobenzene
# 3523                         Chlorobenzene
# 3524                               Undoped
#
#      Perovskite_deposition_quenching_media_additives_compounds  \
# 0                                               Undoped
# 1                                               Undoped
# 2                                               Undoped
# 3                                               Undoped
# 4                                               Undoped
# ...                                                 ...
# 3520                                            Undoped
# 3521                                            Undoped
# 3522                                            Undoped
# 3523                                            Undoped
# 3524                                            Undoped
#
#       Perovskite_deposition_solvent_annealing HTL_stack_sequence  \
# 0                                           0       Spiro-MeOTAD
# 1                                           0       Spiro-MeOTAD
# 2                                           0       Spiro-MeOTAD
# 3                                           0       Spiro-MeOTAD
# 4                                           0       Spiro-MeOTAD
# ...                                       ...                ...
# 3520                                        0       Spiro-MeOTAD
# 3521                                        0       Spiro-MeOTAD
# 3522                                        0       Spiro-MeOTAD
# 3523                                        0       Spiro-MeOTAD
# 3524                                        0               P3HT
#
#      HTL_additives_compounds HTL_deposition_procedure  \
# 0               Li-TFSI; TPB             Spin-coating
# 1               Li-TFSI; TPB             Spin-coating
# 2               Li-TFSI; TPB             Spin-coating
# 3               Li-TFSI; TPB             Spin-coating
# 4               Li-TFSI; TPB             Spin-coating
# ...                      ...                      ...
# 3520     FK209; Li-TFSI; TBP             Spin-coating
# 3521     FK209; Li-TFSI; TBP             Spin-coating
# 3522            Li-TFSI; TBP             Spin-coating
# 3523            Li-TFSI; TBP             Spin-coating
# 3524                 Undoped             Spin-coating
#
#      Backcontact_stack_sequence  Backcontact_thickness_list  \
# 0                            Au                        80.0
# 1                            Au                        80.0
# 2                            Au                        80.0
# 3                            Au                        60.0
# 4                            Au                        80.0
# ...                         ...                         ...
# 3520                         Au                       100.0
# 3521                         Au                       100.0
# 3522                         Au                       100.0
# 3523                         Au                       100.0
# 3524                         Ag                        70.0
#
#      Backcontact_deposition_procedure  JV_default_Voc  JV_default_Jsc  \
# 0                         Evaporation           0.800           20.40
# 1                         Evaporation           0.830           21.30
# 2                         Evaporation           0.870           21.70
# 3                         Evaporation           0.913           15.77
# 4                         Evaporation           1.080           21.70
# ...                               ...             ...             ...
# 3520                      Evaporation           0.925           18.10
# 3521                      Evaporation           0.909           19.05
# 3522                      Evaporation           1.100           22.30
# 3523                      Evaporation           1.090           23.00
# 3524                      Evaporation           0.930           24.10
#
#       JV_default_FF  JV_default_PCE  Perovskite_deposition_solvents_IPA  \
# 0             0.630           10.30                                   0
# 1             0.640           11.50                                   0
# 2             0.660           12.90                                   0
# 3             0.700           10.00                                   0
# 4             0.725           17.00                                   0
# ...             ...             ...                                 ...
# 3520          0.650           11.10                                   1
# 3521          0.690           13.00                                   1
# 3522          0.771           18.90                                   0
# 3523          0.750           18.80                                   0
# 3524          0.714           15.96                                   1
#
#      Perovskite_deposition_thermal_annealing
# 0                                   110-60.0
# 1                                   110-60.0
# 2                                   110-60.0
# 3                                  100.0-5.0
# 4                                  100.0-5.0
# ...                                      ...
# 3520                              100.0-60.0
# 3521                              100.0-60.0
# 3522                              100.0-10.0
# 3523                              100.0-10.0
# 3524                      50.0; 80-3.0; 30.0
#
# [3525 rows x 25 columns]

# %%
from sklearn.preprocessing import LabelEncoder
import time

def LabelEncoder_ifm(feature_name,data,LabelEncoder_dic):
    '''
        feature_name: Name of feature column to be converted
        data: Data that needs to be updated
        LabelEncoder_dic: Dictionary that needs to be stored
    
    '''
    encoder_fit = LabelEncoder().fit(data[feature_name])
    encoder_data = encoder_fit.transform(data[feature_name])

    # Corresponding dictionary before and after encoding
    encoder_dict = dict(zip(encoder_data,encoder_fit.inverse_transform(encoder_data)))
    LabelEncoder_dic = LabelEncoder_dic.update(encoder_dict)
    
    # update
    data[feature_name] = encoder_data

# %%
Cell_architecture_dic={}
LabelEncoder_ifm("Cell_architecture",data,Cell_architecture_dic)
Substrate_stack_sequence_dic={}
LabelEncoder_ifm("Substrate_stack_sequence",data,Substrate_stack_sequence_dic)
ETL_stack_sequence_dic={}
LabelEncoder_ifm("ETL_stack_sequence",data,ETL_stack_sequence_dic)
ETL_additives_compounds_dic={}
LabelEncoder_ifm("ETL_additives_compounds",data,ETL_additives_compounds_dic)
ETL_deposition_procedure_dic={}
LabelEncoder_ifm("ETL_deposition_procedure",data,ETL_deposition_procedure_dic)
Perovskite_composition_perovskite_ABC3_structure_dic={}
LabelEncoder_ifm("Perovskite_composition_perovskite_ABC3_structure",data,Perovskite_composition_perovskite_ABC3_structure_dic)
Perovskite_composition_none_stoichiometry_components_in_excess_dic={}
LabelEncoder_ifm("Perovskite_composition_none_stoichiometry_components_in_excess",data,Perovskite_composition_none_stoichiometry_components_in_excess_dic)
Perovskite_additives_compounds_dic={}
LabelEncoder_ifm("Perovskite_additives_compounds",data,Perovskite_additives_compounds_dic)
Perovskite_deposition_procedure_dic={}
LabelEncoder_ifm("Perovskite_deposition_procedure",data,Perovskite_deposition_procedure_dic)
Perovskite_deposition_solvents_IPA_dic={}
LabelEncoder_ifm("Perovskite_deposition_solvents_IPA",data,Perovskite_deposition_solvents_IPA_dic)
Perovskite_deposition_quenching_media_dic={}
LabelEncoder_ifm("Perovskite_deposition_quenching_media",data,Perovskite_deposition_quenching_media_dic)
Perovskite_deposition_quenching_media_additives_compounds_dic={}
LabelEncoder_ifm("Perovskite_deposition_quenching_media_additives_compounds",data,Perovskite_deposition_quenching_media_additives_compounds_dic)
Perovskite_deposition_thermal_annealing_dic={}
LabelEncoder_ifm("Perovskite_deposition_thermal_annealing",data,Perovskite_deposition_thermal_annealing_dic)
Perovskite_deposition_solvent_annealing_dic={}
LabelEncoder_ifm("Perovskite_deposition_solvent_annealing",data,Perovskite_deposition_solvent_annealing_dic)
HTL_stack_sequence_dic={}
LabelEncoder_ifm("HTL_stack_sequence",data,HTL_stack_sequence_dic)
HTL_additives_compounds_dic={}
LabelEncoder_ifm("HTL_additives_compounds",data,HTL_additives_compounds_dic)
HTL_deposition_procedure_dic={}
LabelEncoder_ifm("HTL_deposition_procedure",data,HTL_deposition_procedure_dic)
Backcontact_stack_sequence_dic={}
LabelEncoder_ifm("Backcontact_stack_sequence",data,Backcontact_stack_sequence_dic)
Backcontact_deposition_procedure_dic={}
LabelEncoder_ifm("Backcontact_deposition_procedure",data,Backcontact_deposition_procedure_dic)

# %%
data["pce"] = data["JV_default_PCE"].apply(lambda x:1 if x>17 else 0)
X = data.drop(columns=['JV_default_PCE','JV_default_Voc','JV_default_Jsc','JV_default_FF',"pce"]).copy()
y = data["pce"].copy()

# %%
best_features = ['Cell_architecture', 'Substrate_stack_sequence', 'ETL_stack_sequence',
       'ETL_additives_compounds', 'ETL_deposition_procedure',
       'Perovskite_composition_none_stoichiometry_components_in_excess',
       'Perovskite_additives_compounds', 'Perovskite_deposition_procedure',
       'DMF_DMSO', 'Perovskite_deposition_quenching_media',
       'HTL_stack_sequence', 'HTL_additives_compounds',
       'Backcontact_stack_sequence', 'Backcontact_thickness_list',
       'Perovskite_deposition_solvents_IPA',
       'Perovskite_deposition_thermal_annealing']

# %% [markdown]
# # Voting model

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
import xgboost
from sklearn.ensemble import VotingClassifier
from imblearn.pipeline import Pipeline
import optuna

seed = 42
rf = RandomForestClassifier(n_estimators=184,
                             criterion='gini',
                             max_depth=18,
                             min_samples_split=2,
                             min_samples_leaf=2,
                             max_features='sqrt',
                             bootstrap=False,
                             n_jobs=-1,
                             random_state=seed) 
xgb = xgboost.XGBClassifier(eta = 0.038816566174682765,
                           max_depth = 10,
                           gamma = 0.22333749634570235, 
                           min_child_weight = 1,
                           subsample = 0.9480060645299058,
                           colsample_bytree = 0.5382666931937315,
                           random_state=42)

voting_names = [
    "Random Forest",
    "XGBoost"
]
voting_classifiers = [
    rf,
    xgb
]

voting_clf =  VotingClassifier(estimators=[(name, model) for name, model in zip(voting_names, voting_classifiers)],
                                        voting='soft', weights=[0.47286297402402977, 0.5310360184667748])

X = X[best_features]
rus = RandomUnderSampler(sampling_strategy=0.38, random_state=42)
X_fit, y_fit = rus.fit_resample(X, y)
smote = SMOTE(sampling_strategy=0.93, random_state=42)
X_fit, y_fit = smote.fit_resample(X_fit, y_fit)
voting_clf.fit(X_fit, y_fit)
# Out:
# VotingClassifier(estimators=[('Random Forest',
#                               RandomForestClassifier(bootstrap=False,
#                                                      max_depth=18,
#                                                      min_samples_leaf=2,
#                                                      n_estimators=184,
#                                                      n_jobs=-1,
#                                                      random_state=42)),
#                              ('XGBoost',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.5382666931937315,
#                                             device=None,
#                                             early_stopping_rounds=None,...
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=10,
#                                             max_leaves=None, min_child_weight=1,
#                                             missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None,
#                                             num_parallel_tree=None, ...))],
#                  voting='soft',
#                  weights=[0.47286297402402977, 0.5310360184667748])

# %% [markdown]
# # Experimental knowledge constraints

# %%
data
# Out:
#       Cell_architecture  Substrate_stack_sequence  ETL_stack_sequence  \
# 0                     0                         0                  16
# 1                     0                         0                  16
# 2                     0                         0                  16
# 3                     0                         0                  12
# 4                     0                         0                  15
# ...                 ...                       ...                 ...
# 3520                  0                         0                  15
# 3521                  0                         0                  15
# 3522                  0                         0                  15
# 3523                  0                         1                  15
# 3524                  0                         0                  12
#
#       ETL_additives_compounds  ETL_deposition_procedure  \
# 0                         116                         3
# 1                           8                         3
# 2                           9                         3
# 3                         116                        10
# 4                          31                        14
# ...                       ...                       ...
# 3520                       20                        17
# 3521                       20                        17
# 3522                       70                        14
# 3523                       70                        14
# 3524                      116                        10
#
#       Perovskite_composition_perovskite_ABC3_structure  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ...                                                ...
# 3520                                                 1
# 3521                                                 1
# 3522                                                 1
# 3523                                                 1
# 3524                                                 1
#
#       Perovskite_composition_none_stoichiometry_components_in_excess  \
# 0                                                    12
# 1                                                    12
# 2                                                    12
# 3                                                    12
# 4                                                     2
# ...                                                 ...
# 3520                                                 12
# 3521                                                 12
# 3522                                                 12
# 3523                                                 12
# 3524                                                 12
#
#       Perovskite_additives_compounds  Perovskite_deposition_procedure  \
# 0                                 83                               11
# 1                                 83                               11
# 2                                 83                               11
# 3                                 83                               11
# 4                                322                               11
# ...                              ...                              ...
# 3520                              38                               18
# 3521                              38                               11
# 3522                             322                               11
# 3523                             322                               11
# 3524                             322                               16
#
#       DMF_DMSO  Perovskite_deposition_quenching_media  \
# 0        1.000                                      8
# 1        1.000                                      8
# 2        1.000                                      8
# 3        1.000                                      8
# 4        1.000                                      8
# ...        ...                                    ...
# 3520     1.000                                      8
# 3521     1.000                                      8
# 3522     0.800                                      2
# 3523     0.800                                      2
# 3524     0.625                                      8
#
#       Perovskite_deposition_quenching_media_additives_compounds  \
# 0                                                     8
# 1                                                     8
# 2                                                     8
# 3                                                     8
# 4                                                     8
# ...                                                 ...
# 3520                                                  8
# 3521                                                  8
# 3522                                                  8
# 3523                                                  8
# 3524                                                  8
#
#       Perovskite_deposition_solvent_annealing  HTL_stack_sequence  \
# 0                                           0                  19
# 1                                           0                  19
# 2                                           0                  19
# 3                                           0                  19
# 4                                           0                  19
# ...                                       ...                 ...
# 3520                                        0                  19
# 3521                                        0                  19
# 3522                                        0                  19
# 3523                                        0                  19
# 3524                                        0                  13
#
#       HTL_additives_compounds  HTL_deposition_procedure  \
# 0                          83                         5
# 1                          83                         5
# 2                          83                         5
# 3                          83                         5
# 4                          83                         5
# ...                       ...                       ...
# 3520                       58                         5
# 3521                       58                         5
# 3522                       80                         5
# 3523                       80                         5
# 3524                      114                         5
#
#       Backcontact_stack_sequence  Backcontact_thickness_list  \
# 0                              3                        80.0
# 1                              3                        80.0
# 2                              3                        80.0
# 3                              3                        60.0
# 4                              3                        80.0
# ...                          ...                         ...
# 3520                           3                       100.0
# 3521                           3                       100.0
# 3522                           3                       100.0
# 3523                           3                       100.0
# 3524                           0                        70.0
#
#       Backcontact_deposition_procedure  JV_default_Voc  JV_default_Jsc  \
# 0                                    1           0.800           20.40
# 1                                    1           0.830           21.30
# 2                                    1           0.870           21.70
# 3                                    1           0.913           15.77
# 4                                    1           1.080           21.70
# ...                                ...             ...             ...
# 3520                                 1           0.925           18.10
# 3521                                 1           0.909           19.05
# 3522                                 1           1.100           22.30
# 3523                                 1           1.090           23.00
# 3524                                 1           0.930           24.10
#
#       JV_default_FF  JV_default_PCE  Perovskite_deposition_solvents_IPA  \
# 0             0.630           10.30                                   0
# 1             0.640           11.50                                   0
# 2             0.660           12.90                                   0
# 3             0.700           10.00                                   0
# 4             0.725           17.00                                   0
# ...             ...             ...                                 ...
# 3520          0.650           11.10                                   1
# 3521          0.690           13.00                                   1
# 3522          0.771           18.90                                   0
# 3523          0.750           18.80                                   0
# 3524          0.714           15.96                                   1
#
#       Perovskite_deposition_thermal_annealing  pce
# 0                                          75    0
# 1                                          75    0
# 2                                          75    0
# 3                                          30    0
# 4                                          30    0
# ...                                       ...  ...
# 3520                                       34    0
# 3521                                       34    0
# 3522                                        8    1
# 3523                                        8    1
# 3524                                      221    0
#
# [3525 rows x 26 columns]

# %%
Cell_architecture_dic
# Out:
# {0: 'nip', 1: 'pin'}

# %% [markdown]
# ## ETL

# %% [markdown]
# ### nip

# %%
# Cell_architecture = 0, {ETL_stack_sequence, ETL_additives_compounds,ETL_deposition_procedure}
data_nip = data[data["Cell_architecture"] == 0]
etl = []
etl_add = []
etl_pro = []
for index in data_nip['ETL_stack_sequence'].unique():
    add = data_nip[data_nip['ETL_stack_sequence'] == index]['ETL_additives_compounds'].unique()
    for i in add:
        pro = data_nip[(data_nip['ETL_stack_sequence'] == index)&(data_nip['ETL_additives_compounds'] == i)]['ETL_deposition_procedure'].unique()
        for j in pro:
            etl.append(index)
            etl_add.append(i)
            etl_pro.append(j)
    

ETL_nip = pd.DataFrame({"etl": etl, "etl_add": etl_add,"etl_pro":etl_pro})
ETL_nip
# Out:
#      etl  etl_add  etl_pro
# 0     16      116        3
# 1     16      116       14
# 2     16      116       13
# 3     16        8        3
# 4     16        9        3
# ..   ...      ...      ...
# 163   18        0       13
# 164   19      116       10
# 165   19       72       10
# 166   10      116       14
# 167    7      116       14
#
# [168 rows x 3 columns]

# %%
etl_nip = ETL_nip.to_numpy().tolist()
etl_nip_dic={}
for index in range(len(etl_nip)):
    etl_nip_dic[index] = etl_nip[index]
    
etl_nip_dic
# Out:
# {0: [16, 116, 3],
#  1: [16, 116, 14],
#  2: [16, 116, 13],
#  3: [16, 8, 3],
#  4: [16, 9, 3],
#  5: [16, 31, 14],
#  6: [16, 22, 3],
#  7: [16, 120, 3],
#  8: [12, 116, 10],
#  9: [12, 116, 16],
#  10: [12, 116, 2],
#  11: [12, 116, 5],
#  12: [12, 116, 8],
#  13: [12, 116, 14],
#  14: [12, 116, 18],
#  15: [12, 116, 0],
#  16: [12, 116, 7],
#  17: [12, 69, 10],
#  18: [12, 111, 10],
#  19: [12, 111, 16],
#  20: [12, 111, 0],
#  21: [12, 76, 10],
#  22: [12, 35, 10],
#  23: [12, 48, 10],
#  24: [12, 44, 0],
#  25: [12, 128, 10],
#  26: [12, 118, 10],
#  27: [12, 62, 10],
#  28: [12, 43, 10],
#  29: [12, 107, 10],
#  30: [12, 107, 14],
#  31: [12, 83, 16],
#  32: [12, 63, 10],
#  33: [12, 36, 10],
#  34: [12, 97, 16],
#  35: [12, 71, 10],
#  36: [12, 57, 10],
#  37: [12, 82, 2],
#  38: [12, 99, 10],
#  39: [12, 31, 10],
#  40: [12, 117, 10],
#  41: [12, 119, 10],
#  42: [12, 79, 10],
#  43: [12, 93, 10],
#  44: [12, 100, 10],
#  45: [12, 94, 2],
#  46: [12, 81, 10],
#  47: [12, 109, 10],
#  48: [15, 31, 14],
#  49: [15, 31, 17],
#  50: [15, 31, 1],
#  51: [15, 31, 6],
#  52: [15, 31, 15],
#  53: [15, 116, 14],
#  54: [15, 116, 17],
#  55: [15, 116, 2],
#  56: [15, 116, 1],
#  57: [15, 116, 6],
#  58: [15, 116, 19],
#  59: [15, 116, 11],
#  60: [15, 116, 4],
#  61: [15, 116, 10],
#  62: [15, 101, 14],
#  63: [15, 20, 17],
#  64: [15, 20, 14],
#  65: [15, 112, 14],
#  66: [15, 112, 17],
#  67: [15, 113, 14],
#  68: [15, 98, 14],
#  69: [15, 114, 17],
#  70: [15, 85, 14],
#  71: [15, 12, 6],
#  72: [15, 5, 17],
#  73: [15, 14, 17],
#  74: [15, 65, 17],
#  75: [15, 67, 14],
#  76: [15, 18, 17],
#  77: [15, 34, 14],
#  78: [15, 13, 14],
#  79: [15, 15, 17],
#  80: [15, 27, 14],
#  81: [15, 16, 14],
#  82: [15, 26, 14],
#  83: [15, 33, 14],
#  84: [15, 84, 17],
#  85: [15, 108, 17],
#  86: [15, 1, 14],
#  87: [15, 2, 14],
#  88: [15, 30, 14],
#  89: [15, 61, 14],
#  90: [15, 58, 14],
#  91: [15, 21, 14],
#  92: [15, 10, 14],
#  93: [15, 24, 14],
#  94: [15, 4, 14],
#  95: [15, 6, 17],
#  96: [15, 23, 17],
#  97: [15, 59, 17],
#  98: [15, 29, 17],
#  99: [15, 25, 17],
#  100: [15, 19, 17],
#  101: [15, 11, 14],
#  102: [15, 28, 14],
#  103: [15, 70, 14],
#  104: [15, 32, 14],
#  105: [15, 115, 14],
#  106: [15, 127, 15],
#  107: [15, 127, 17],
#  108: [15, 127, 14],
#  109: [15, 124, 17],
#  110: [15, 125, 14],
#  111: [15, 126, 14],
#  112: [15, 122, 14],
#  113: [15, 123, 14],
#  114: [0, 116, 8],
#  115: [0, 116, 10],
#  116: [0, 75, 10],
#  117: [17, 116, 10],
#  118: [17, 116, 2],
#  119: [17, 116, 18],
#  120: [17, 116, 16],
#  121: [17, 116, 8],
#  122: [17, 116, 0],
#  123: [17, 78, 10],
#  124: [17, 78, 18],
#  125: [17, 60, 10],
#  126: [9, 116, 10],
#  127: [9, 116, 18],
#  128: [9, 116, 2],
#  129: [9, 116, 16],
#  130: [9, 116, 8],
#  131: [9, 116, 0],
#  132: [9, 66, 10],
#  133: [9, 74, 10],
#  134: [9, 38, 10],
#  135: [9, 73, 10],
#  136: [9, 40, 10],
#  137: [9, 102, 10],
#  138: [9, 80, 10],
#  139: [9, 110, 10],
#  140: [11, 116, 10],
#  141: [11, 96, 10],
#  142: [11, 36, 10],
#  143: [11, 119, 10],
#  144: [11, 68, 10],
#  145: [14, 116, 14],
#  146: [14, 116, 4],
#  147: [14, 116, 11],
#  148: [14, 116, 19],
#  149: [14, 116, 17],
#  150: [14, 7, 14],
#  151: [2, 116, 10],
#  152: [2, 47, 10],
#  153: [13, 116, 14],
#  154: [13, 116, 1],
#  155: [13, 116, 17],
#  156: [13, 3, 17],
#  157: [13, 37, 14],
#  158: [3, 116, 14],
#  159: [3, 116, 11],
#  160: [18, 116, 13],
#  161: [18, 17, 13],
#  162: [18, 21, 13],
#  163: [18, 0, 13],
#  164: [19, 116, 10],
#  165: [19, 72, 10],
#  166: [10, 116, 14],
#  167: [7, 116, 14]}

# %% [markdown]
# ### pin

# %%
# Cell_architecture = 1, {ETL_stack_sequence, ETL_additives_compounds,ETL_deposition_procedure}
data_pin = data[data["Cell_architecture"] == 1]
etl = []
etl_add = []
etl_pro = []
for index in data_pin['ETL_stack_sequence'].unique():
    add = data_pin[data_pin['ETL_stack_sequence'] == index]['ETL_additives_compounds'].unique()
    for i in add:
        pro = data_pin[(data_pin['ETL_stack_sequence'] == index)&(data_pin['ETL_additives_compounds'] == i)]['ETL_deposition_procedure'].unique()
        for j in pro:
            etl.append(index)
            etl_add.append(i)
            etl_pro.append(j)
    

ETL_pin = pd.DataFrame({"etl": etl, "etl_add": etl_add,"etl_pro":etl_pro})
etl_pin = ETL_pin.to_numpy().tolist()
etl_pin_dic={}
for index in range(len(etl_pin)):
    etl_pin_dic[index] = etl_pin[index]
    
etl_pin_dic
# Out:
# {0: [4, 116, 11],
#  1: [4, 116, 14],
#  2: [2, 116, 10],
#  3: [2, 116, 14],
#  4: [2, 116, 11],
#  5: [2, 39, 10],
#  6: [2, 103, 10],
#  7: [2, 51, 10],
#  8: [2, 46, 10],
#  9: [2, 45, 10],
#  10: [2, 87, 10],
#  11: [2, 86, 10],
#  12: [2, 88, 10],
#  13: [2, 95, 10],
#  14: [2, 89, 10],
#  15: [2, 49, 10],
#  16: [2, 121, 10],
#  17: [2, 64, 10],
#  18: [2, 104, 10],
#  19: [2, 106, 10],
#  20: [2, 105, 10],
#  21: [2, 41, 10],
#  22: [2, 92, 10],
#  23: [3, 116, 9],
#  24: [3, 116, 14],
#  25: [3, 116, 11],
#  26: [3, 129, 14],
#  27: [3, 52, 14],
#  28: [3, 53, 14],
#  29: [3, 90, 14],
#  30: [3, 77, 14],
#  31: [1, 116, 9],
#  32: [1, 116, 8],
#  33: [1, 116, 12],
#  34: [8, 116, 14],
#  35: [5, 116, 12],
#  36: [6, 116, 11],
#  37: [6, 50, 11],
#  38: [6, 91, 11],
#  39: [7, 116, 14],
#  40: [17, 116, 18],
#  41: [11, 116, 10],
#  42: [12, 116, 10],
#  43: [0, 116, 8],
#  44: [0, 56, 8],
#  45: [0, 55, 8],
#  46: [0, 54, 8],
#  47: [18, 116, 13],
#  48: [16, 116, 14],
#  49: [19, 116, 10],
#  50: [19, 42, 10],
#  51: [15, 127, 14]}

# %% [markdown]
# ## HTL

# %% [markdown]
# ### nip

# %%
# Cell_architecture = 0, {HTL_stack_sequence, HTL_additives_compounds,HTL_deposition_procedure}
htl = []
htl_add = []
# htl_pro = []
for index in data_nip['HTL_stack_sequence'].unique():
    add = data_nip[data_nip['HTL_stack_sequence'] == index]['HTL_additives_compounds'].unique()
    for i in add:
#         pro = data_nip[(data_nip['HTL_stack_sequence'] == index)&(data_nip['HTL_additives_compounds'] == i)]['HTL_deposition_procedure'].unique()
#         for j in pro:
        htl.append(index)
        htl_add.append(i)
#         htl_pro.append(j)


# HTL_nip = pd.DataFrame({"htl": htl, "htl_add": htl_add,"htl_pro":htl_pro})
HTL_nip = pd.DataFrame({"htl": htl, "htl_add": htl_add})
htl_nip = HTL_nip.to_numpy().tolist()
htl_nip_dic={}
for index in range(len(htl_nip)):
    htl_nip_dic[index] = htl_nip[index]
    
htl_nip_dic
# Out:
# {0: [19, 83],
#  1: [19, 80],
#  2: [19, 114],
#  3: [19, 70],
#  4: [19, 71],
#  5: [19, 72],
#  6: [19, 58],
#  7: [19, 75],
#  8: [19, 27],
#  9: [19, 12],
#  10: [19, 13],
#  11: [19, 51],
#  12: [19, 61],
#  13: [19, 53],
#  14: [19, 19],
#  15: [19, 52],
#  16: [19, 79],
#  17: [19, 24],
#  18: [19, 25],
#  19: [19, 26],
#  20: [19, 55],
#  21: [19, 109],
#  22: [19, 77],
#  23: [19, 2],
#  24: [19, 82],
#  25: [19, 22],
#  26: [19, 69],
#  27: [19, 41],
#  28: [19, 104],
#  29: [19, 4],
#  30: [19, 3],
#  31: [19, 85],
#  32: [19, 48],
#  33: [19, 87],
#  34: [19, 37],
#  35: [19, 38],
#  36: [19, 39],
#  37: [19, 40],
#  38: [19, 106],
#  39: [19, 50],
#  40: [19, 68],
#  41: [19, 10],
#  42: [19, 76],
#  43: [19, 33],
#  44: [19, 23],
#  45: [19, 56],
#  46: [19, 54],
#  47: [19, 57],
#  48: [19, 81],
#  49: [19, 78],
#  50: [19, 59],
#  51: [19, 60],
#  52: [19, 21],
#  53: [19, 34],
#  54: [19, 32],
#  55: [16, 80],
#  56: [16, 114],
#  57: [16, 48],
#  58: [16, 77],
#  59: [16, 73],
#  60: [16, 75],
#  61: [16, 110],
#  62: [16, 96],
#  63: [3, 114],
#  64: [13, 80],
#  65: [13, 114],
#  66: [13, 75],
#  67: [13, 36],
#  68: [13, 35],
#  69: [13, 100],
#  70: [13, 67],
#  71: [13, 101],
#  72: [13, 20],
#  73: [13, 77],
#  74: [13, 85],
#  75: [13, 48],
#  76: [13, 47],
#  77: [18, 114],
#  78: [15, 114],
#  79: [9, 114],
#  80: [7, 114],
#  81: [7, 90],
#  82: [0, 114],
#  83: [2, 114],
#  84: [11, 114],
#  85: [6, 114],
#  86: [4, 1],
#  87: [14, 114]}

# %% [markdown]
# ### pin

# %%
# Cell_architecture = 1, {HTL_stack_sequence, HTL_additives_compounds,HTL_deposition_procedure}
htl = []
htl_add = []
htl_pro = []
for index in data_pin['HTL_stack_sequence'].unique():
    add = data_pin[data_pin['HTL_stack_sequence'] == index]['HTL_additives_compounds'].unique()
    for i in add:
#         pro = data_pin[(data_pin['HTL_stack_sequence'] == index)&(data_pin['HTL_additives_compounds'] == i)]['HTL_deposition_procedure'].unique()
#         for j in pro:
            htl.append(index)
            htl_add.append(i)
#             htl_pro.append(j)
    

# HTL_pin = pd.DataFrame({"htl": htl, "htl_add": htl_add,"htl_pro":htl_pro})
HTL_pin = pd.DataFrame({"htl": htl, "htl_add": htl_add})
htl_pin = HTL_pin.to_numpy().tolist()
htl_pin_dic={}
for index in range(len(htl_pin)):
    htl_pin_dic[index] = htl_pin[index]
    
htl_pin_dic
# Out:
# {0: [16, 114],
#  1: [16, 103],
#  2: [16, 48],
#  3: [16, 92],
#  4: [16, 49],
#  5: [16, 108],
#  6: [15, 114],
#  7: [15, 93],
#  8: [15, 80],
#  9: [15, 91],
#  10: [15, 17],
#  11: [15, 118],
#  12: [15, 111],
#  13: [15, 5],
#  14: [15, 64],
#  15: [15, 7],
#  16: [15, 98],
#  17: [15, 95],
#  18: [15, 11],
#  19: [15, 88],
#  20: [15, 42],
#  21: [15, 97],
#  22: [15, 89],
#  23: [15, 44],
#  24: [15, 65],
#  25: [15, 120],
#  26: [15, 28],
#  27: [15, 105],
#  28: [15, 15],
#  29: [15, 113],
#  30: [7, 30],
#  31: [7, 114],
#  32: [7, 117],
#  33: [7, 20],
#  34: [7, 75],
#  35: [7, 74],
#  36: [7, 6],
#  37: [7, 8],
#  38: [7, 115],
#  39: [7, 102],
#  40: [7, 9],
#  41: [7, 99],
#  42: [7, 84],
#  43: [7, 29],
#  44: [7, 86],
#  45: [7, 16],
#  46: [7, 107],
#  47: [7, 14],
#  48: [7, 46],
#  49: [7, 116],
#  50: [7, 112],
#  51: [7, 18],
#  52: [7, 94],
#  53: [7, 43],
#  54: [7, 45],
#  55: [9, 114],
#  56: [9, 119],
#  57: [9, 30],
#  58: [9, 20],
#  59: [9, 62],
#  60: [12, 114],
#  61: [8, 114],
#  62: [8, 31],
#  63: [8, 0],
#  64: [19, 80],
#  65: [19, 114],
#  66: [19, 58],
#  67: [13, 114],
#  68: [5, 114],
#  69: [18, 114],
#  70: [18, 48],
#  71: [6, 114],
#  72: [11, 114],
#  73: [0, 114],
#  74: [14, 63],
#  75: [14, 114],
#  76: [1, 114],
#  77: [3, 114],
#  78: [3, 48],
#  79: [10, 114],
#  80: [10, 66],
#  81: [17, 114]}

# %% [markdown]
# ## PVK

# %%
# MAPbI3,{Perovskite_additives_compounds,Perovskite_deposition_procedure,Perovskite_deposition_quenching_media,Perovskite_deposition_quenching_media_additives_compounds}
pvk_add = []
pvkm = []
pvkm_add = []
pvk_pro = []
for add in data['Perovskite_additives_compounds'].unique():
    for index in data['Perovskite_deposition_quenching_media'].unique():
        m_add = data[data['Perovskite_deposition_quenching_media'] == index]['Perovskite_deposition_quenching_media_additives_compounds'].unique()
        for i in m_add:
            pro = data[(data['Perovskite_deposition_quenching_media'] == index)&(data['Perovskite_additives_compounds'] == add)]['Perovskite_deposition_procedure'].unique()
            for j in pro:
                pvk_add.append(add)
                pvkm.append(index)
                pvkm_add.append(i)
                pvk_pro.append(j)
    

PVK = pd.DataFrame({"pvk_add":pvk_add,"pvk_pro":pvk_pro,"pvkm": pvkm, "pvkm_add": pvkm_add})

pvkm_list = PVK.to_numpy().tolist()
pvkm_list_dic={}
for index in range(len(pvkm_list)):
    pvkm_list_dic[index] = pvkm_list[index]

pvkm_list_dic
# Out:
# {0: [83, 11, 8, 8],
#  1: [83, 16, 8, 8],
#  2: [83, 6, 8, 8],
#  3: [83, 12, 8, 8],
#  4: [83, 10, 8, 8],
#  5: [83, 2, 8, 8],
#  6: [83, 1, 8, 8],
#  7: [83, 7, 8, 8],
#  8: [83, 14, 8, 8],
#  9: [83, 18, 8, 8],
#  10: [83, 9, 8, 8],
#  11: [83, 5, 8, 8],
#  12: [83, 0, 8, 8],
#  13: [83, 11, 2, 8],
#  14: [83, 16, 2, 8],
#  15: [83, 12, 2, 8],
#  16: [83, 0, 2, 8],
#  17: [83, 11, 2, 7],
#  18: [83, 16, 2, 7],
#  19: [83, 12, 2, 7],
#  20: [83, 0, 2, 7],
#  21: [83, 11, 2, 6],
#  22: [83, 16, 2, 6],
#  23: [83, 12, 2, 6],
#  24: [83, 0, 2, 6],
#  25: [83, 11, 2, 5],
#  26: [83, 16, 2, 5],
#  27: [83, 12, 2, 5],
#  28: [83, 0, 2, 5],
#  29: [83, 11, 2, 4],
#  30: [83, 16, 2, 4],
#  31: [83, 12, 2, 4],
#  32: [83, 0, 2, 4],
#  33: [83, 11, 2, 2],
#  34: [83, 16, 2, 2],
#  35: [83, 12, 2, 2],
#  36: [83, 0, 2, 2],
#  37: [83, 11, 2, 3],
#  38: [83, 16, 2, 3],
#  39: [83, 12, 2, 3],
#  40: [83, 0, 2, 3],
#  41: [83, 11, 4, 8],
#  42: [83, 11, 3, 8],
#  43: [83, 11, 3, 0],
#  44: [83, 11, 3, 3],
#  45: [83, 11, 3, 1],
#  46: [83, 11, 7, 8],
#  47: [83, 16, 9, 8],
#  48: [83, 11, 9, 8],
#  49: [83, 3, 9, 8],
#  50: [322, 11, 8, 8],
#  51: [322, 12, 8, 8],
#  52: [322, 16, 8, 8],
#  53: [322, 18, 8, 8],
#  54: [322, 19, 8, 8],
#  55: [322, 2, 8, 8],
#  56: [322, 10, 8, 8],
#  57: [322, 5, 8, 8],
#  58: [322, 17, 8, 8],
#  59: [322, 3, 8, 8],
#  60: [322, 14, 8, 8],
#  61: [322, 4, 8, 8],
#  62: [322, 0, 8, 8],
#  63: [322, 8, 8, 8],
#  64: [322, 9, 8, 8],
#  65: [322, 11, 2, 8],
#  66: [322, 16, 2, 8],
#  67: [322, 2, 2, 8],
#  68: [322, 12, 2, 8],
#  69: [322, 9, 2, 8],
#  70: [322, 14, 2, 8],
#  71: [322, 3, 2, 8],
#  72: [322, 4, 2, 8],
#  73: [322, 0, 2, 8],
#  74: [322, 15, 2, 8],
#  75: [322, 8, 2, 8],
#  76: [322, 18, 2, 8],
#  77: [322, 11, 2, 7],
#  78: [322, 16, 2, 7],
#  79: [322, 2, 2, 7],
#  80: [322, 12, 2, 7],
#  81: [322, 9, 2, 7],
#  82: [322, 14, 2, 7],
#  83: [322, 3, 2, 7],
#  84: [322, 4, 2, 7],
#  85: [322, 0, 2, 7],
#  86: [322, 15, 2, 7],
#  87: [322, 8, 2, 7],
#  88: [322, 18, 2, 7],
#  89: [322, 11, 2, 6],
#  90: [322, 16, 2, 6],
#  91: [322, 2, 2, 6],
#  92: [322, 12, 2, 6],
#  93: [322, 9, 2, 6],
#  94: [322, 14, 2, 6],
#  95: [322, 3, 2, 6],
#  96: [322, 4, 2, 6],
#  97: [322, 0, 2, 6],
#  98: [322, 15, 2, 6],
#  99: [322, 8, 2, 6],
#  100: [322, 18, 2, 6],
#  101: [322, 11, 2, 5],
#  102: [322, 16, 2, 5],
#  103: [322, 2, 2, 5],
#  104: [322, 12, 2, 5],
#  105: [322, 9, 2, 5],
#  106: [322, 14, 2, 5],
#  107: [322, 3, 2, 5],
#  108: [322, 4, 2, 5],
#  109: [322, 0, 2, 5],
#  110: [322, 15, 2, 5],
#  111: [322, 8, 2, 5],
#  112: [322, 18, 2, 5],
#  113: [322, 11, 2, 4],
#  114: [322, 16, 2, 4],
#  115: [322, 2, 2, 4],
#  116: [322, 12, 2, 4],
#  117: [322, 9, 2, 4],
#  118: [322, 14, 2, 4],
#  119: [322, 3, 2, 4],
#  120: [322, 4, 2, 4],
#  121: [322, 0, 2, 4],
#  122: [322, 15, 2, 4],
#  123: [322, 8, 2, 4],
#  124: [322, 18, 2, 4],
#  125: [322, 11, 2, 2],
#  126: [322, 16, 2, 2],
#  127: [322, 2, 2, 2],
#  128: [322, 12, 2, 2],
#  129: [322, 9, 2, 2],
#  130: [322, 14, 2, 2],
#  131: [322, 3, 2, 2],
#  132: [322, 4, 2, 2],
#  133: [322, 0, 2, 2],
#  134: [322, 15, 2, 2],
#  135: [322, 8, 2, 2],
#  136: [322, 18, 2, 2],
#  137: [322, 11, 2, 3],
#  138: [322, 16, 2, 3],
#  139: [322, 2, 2, 3],
#  140: [322, 12, 2, 3],
#  141: [322, 9, 2, 3],
#  142: [322, 14, 2, 3],
#  143: [322, 3, 2, 3],
#  144: [322, 4, 2, 3],
#  145: [322, 0, 2, 3],
#  146: [322, 15, 2, 3],
#  147: [322, 8, 2, 3],
#  148: [322, 18, 2, 3],
#  149: [322, 11, 4, 8],
#  150: [322, 12, 4, 8],
#  151: [322, 16, 4, 8],
#  152: [322, 11, 3, 8],
#  153: [322, 16, 3, 8],
#  154: [322, 12, 3, 8],
#  155: [322, 0, 3, 8],
#  156: [322, 6, 3, 8],
#  157: [322, 14, 3, 8],
#  158: [322, 18, 3, 8],
#  159: [322, 3, 3, 8],
#  160: [322, 8, 3, 8],
#  161: [322, 11, 3, 0],
#  162: [322, 16, 3, 0],
#  163: [322, 12, 3, 0],
#  164: [322, 0, 3, 0],
#  165: [322, 6, 3, 0],
#  166: [322, 14, 3, 0],
#  167: [322, 18, 3, 0],
#  168: [322, 3, 3, 0],
#  169: [322, 8, 3, 0],
#  170: [322, 11, 3, 3],
#  171: [322, 16, 3, 3],
#  172: [322, 12, 3, 3],
#  173: [322, 0, 3, 3],
#  174: [322, 6, 3, 3],
#  175: [322, 14, 3, 3],
#  176: [322, 18, 3, 3],
#  177: [322, 3, 3, 3],
#  178: [322, 8, 3, 3],
#  179: [322, 11, 3, 1],
#  180: [322, 16, 3, 1],
#  181: [322, 12, 3, 1],
#  182: [322, 0, 3, 1],
#  183: [322, 6, 3, 1],
#  184: [322, 14, 3, 1],
#  185: [322, 18, 3, 1],
#  186: [322, 3, 3, 1],
#  187: [322, 8, 3, 1],
#  188: [322, 11, 0, 8],
#  189: [322, 11, 7, 8],
#  190: [322, 12, 7, 8],
#  191: [322, 2, 7, 8],
#  192: [322, 16, 7, 8],
#  193: [322, 4, 7, 8],
#  194: [322, 0, 7, 8],
#  195: [322, 13, 7, 8],
#  196: [322, 11, 9, 8],
#  197: [322, 10, 9, 8],
#  198: [322, 16, 9, 8],
#  199: [322, 12, 9, 8],
#  200: [322, 11, 1, 8],
#  201: [322, 0, 1, 8],
#  202: [322, 16, 1, 8],
#  203: [322, 11, 6, 8],
#  204: [322, 10, 6, 8],
#  205: [322, 12, 6, 8],
#  206: [322, 9, 6, 8],
#  207: [322, 4, 6, 8],
#  208: [322, 11, 5, 8],
#  209: [322, 3, 5, 8],
#  210: [322, 16, 5, 8],
#  211: [42, 12, 8, 8],
#  212: [111, 11, 8, 8],
#  213: [104, 11, 8, 8],
#  214: [189, 11, 8, 8],
#  215: [131, 11, 2, 8],
#  216: [131, 11, 2, 7],
#  217: [131, 11, 2, 6],
#  218: [131, 11, 2, 5],
#  219: [131, 11, 2, 4],
#  220: [131, 11, 2, 2],
#  221: [131, 11, 2, 3],
#  222: [84, 11, 8, 8],
#  223: [269, 16, 8, 8],
#  224: [269, 11, 8, 8],
#  225: [269, 11, 2, 8],
#  226: [269, 11, 2, 7],
#  227: [269, 11, 2, 6],
#  228: [269, 11, 2, 5],
#  229: [269, 11, 2, 4],
#  230: [269, 11, 2, 2],
#  231: [269, 11, 2, 3],
#  232: [269, 11, 3, 8],
#  233: [269, 11, 3, 0],
#  234: [269, 11, 3, 3],
#  235: [269, 11, 3, 1],
#  236: [269, 5, 6, 8],
#  237: [269, 11, 5, 8],
#  238: [5, 11, 8, 8],
#  239: [6, 11, 8, 8],
#  240: [170, 11, 2, 8],
#  241: [170, 11, 2, 7],
#  242: [170, 11, 2, 6],
#  243: [170, 11, 2, 5],
#  244: [170, 11, 2, 4],
#  245: [170, 11, 2, 2],
#  246: [170, 11, 2, 3],
#  247: [260, 11, 8, 8],
#  248: [186, 11, 8, 8],
#  249: [94, 11, 8, 8],
#  250: [13, 11, 2, 8],
#  251: [13, 11, 2, 7],
#  252: [13, 11, 2, 6],
#  253: [13, 11, 2, 5],
#  254: [13, 11, 2, 4],
#  255: [13, 11, 2, 2],
#  256: [13, 11, 2, 3],
#  257: [335, 11, 2, 8],
#  258: [335, 11, 2, 7],
#  259: [335, 11, 2, 6],
#  260: [335, 11, 2, 5],
#  261: [335, 11, 2, 4],
#  262: [335, 11, 2, 2],
#  263: [335, 11, 2, 3],
#  264: [337, 14, 8, 8],
#  265: [337, 11, 2, 8],
#  266: [337, 11, 2, 7],
#  267: [337, 11, 2, 6],
#  268: [337, 11, 2, 5],
#  269: [337, 11, 2, 4],
#  270: [337, 11, 2, 2],
#  271: [337, 11, 2, 3],
#  272: [142, 11, 2, 8],
#  273: [142, 11, 2, 7],
#  274: [142, 11, 2, 6],
#  275: [142, 11, 2, 5],
#  276: [142, 11, 2, 4],
#  277: [142, 11, 2, 2],
#  278: [142, 11, 2, 3],
#  279: [176, 16, 8, 8],
#  280: [176, 11, 2, 8],
#  281: [176, 11, 2, 7],
#  282: [176, 11, 2, 6],
#  283: [176, 11, 2, 5],
#  284: [176, 11, 2, 4],
#  285: [176, 11, 2, 2],
#  286: [176, 11, 2, 3],
#  287: [176, 11, 3, 8],
#  288: [176, 11, 3, 0],
#  289: [176, 11, 3, 3],
#  290: [176, 11, 3, 1],
#  291: [176, 11, 7, 8],
#  292: [298, 11, 3, 8],
#  293: [298, 11, 3, 0],
#  294: [298, 11, 3, 3],
#  295: [298, 11, 3, 1],
#  296: [243, 11, 2, 8],
#  297: [243, 11, 2, 7],
#  298: [243, 11, 2, 6],
#  299: [243, 11, 2, 5],
#  300: [243, 11, 2, 4],
#  301: [243, 11, 2, 2],
#  302: [243, 11, 2, 3],
#  303: [26, 11, 8, 8],
#  304: [26, 10, 8, 8],
#  305: [332, 11, 7, 8],
#  306: [318, 11, 7, 8],
#  307: [256, 11, 8, 8],
#  308: [256, 11, 2, 8],
#  309: [256, 16, 2, 8],
#  310: [256, 11, 2, 7],
#  311: [256, 16, 2, 7],
#  312: [256, 11, 2, 6],
#  313: [256, 16, 2, 6],
#  314: [256, 11, 2, 5],
#  315: [256, 16, 2, 5],
#  316: [256, 11, 2, 4],
#  317: [256, 16, 2, 4],
#  318: [256, 11, 2, 2],
#  319: [256, 16, 2, 2],
#  320: [256, 11, 2, 3],
#  321: [256, 16, 2, 3],
#  322: [256, 11, 3, 8],
#  323: [256, 11, 3, 0],
#  324: [256, 11, 3, 3],
#  325: [256, 11, 3, 1],
#  326: [71, 11, 8, 8],
#  327: [212, 11, 8, 8],
#  328: [130, 11, 3, 8],
#  329: [130, 11, 3, 0],
#  330: [130, 11, 3, 3],
#  331: [130, 11, 3, 1],
#  332: [244, 11, 2, 8],
#  333: [244, 11, 2, 7],
#  334: [244, 11, 2, 6],
#  335: [244, 11, 2, 5],
#  336: [244, 11, 2, 4],
#  337: [244, 11, 2, 2],
#  338: [244, 11, 2, 3],
#  339: [202, 16, 8, 8],
#  340: [203, 16, 8, 8],
#  341: [204, 16, 8, 8],
#  342: [116, 11, 8, 8],
#  343: [255, 11, 2, 8],
#  344: [255, 11, 2, 7],
#  345: [255, 11, 2, 6],
#  346: [255, 11, 2, 5],
#  347: [255, 11, 2, 4],
#  348: [255, 11, 2, 2],
#  349: [255, 11, 2, 3],
#  350: [157, 11, 8, 8],
#  351: [32, 16, 8, 8],
#  352: [228, 11, 8, 8],
#  353: [223, 12, 8, 8],
#  354: [114, 11, 8, 8],
#  355: [185, 11, 8, 8],
#  356: [185, 5, 8, 8],
#  357: [185, 16, 8, 8],
#  358: [185, 12, 8, 8],
#  359: [24, 11, 2, 8],
#  360: [24, 11, 2, 7],
#  361: [24, 11, 2, 6],
#  362: [24, 11, 2, 5],
#  363: [24, 11, 2, 4],
#  364: [24, 11, 2, 2],
#  365: [24, 11, 2, 3],
#  366: [163, 11, 8, 8],
#  367: [180, 11, 8, 8],
#  368: [123, 11, 8, 8],
#  369: [122, 11, 8, 8],
#  370: [121, 11, 8, 8],
#  371: [120, 11, 8, 8],
#  372: [305, 11, 8, 8],
#  373: [54, 11, 8, 8],
#  374: [57, 11, 8, 8],
#  375: [69, 11, 8, 8],
#  376: [69, 11, 2, 8],
#  377: [69, 11, 2, 7],
#  378: [69, 11, 2, 6],
#  379: [69, 11, 2, 5],
#  380: [69, 11, 2, 4],
#  381: [69, 11, 2, 2],
#  382: [69, 11, 2, 3],
#  383: [18, 11, 8, 8],
#  384: [283, 11, 7, 8],
#  385: [285, 11, 7, 8],
#  386: [44, 11, 8, 8],
#  387: [44, 11, 2, 8],
#  388: [44, 11, 2, 7],
#  389: [44, 11, 2, 6],
#  390: [44, 11, 2, 5],
#  391: [44, 11, 2, 4],
#  392: [44, 11, 2, 2],
#  393: [44, 11, 2, 3],
#  394: [254, 11, 8, 8],
#  395: [254, 12, 8, 8],
#  396: [254, 16, 8, 8],
#  397: [254, 11, 2, 8],
#  398: [254, 11, 2, 7],
#  399: [254, 11, 2, 6],
#  400: [254, 11, 2, 5],
#  401: [254, 11, 2, 4],
#  402: [254, 11, 2, 2],
#  403: [254, 11, 2, 3],
#  404: [89, 16, 8, 8],
#  405: [133, 11, 7, 8],
#  406: [60, 11, 2, 8],
#  407: [60, 11, 2, 7],
#  408: [60, 11, 2, 6],
#  409: [60, 11, 2, 5],
#  410: [60, 11, 2, 4],
#  411: [60, 11, 2, 2],
#  412: [60, 11, 2, 3],
#  413: [60, 11, 4, 8],
#  414: [168, 11, 2, 8],
#  415: [168, 11, 2, 7],
#  416: [168, 11, 2, 6],
#  417: [168, 11, 2, 5],
#  418: [168, 11, 2, 4],
#  419: [168, 11, 2, 2],
#  420: [168, 11, 2, 3],
#  421: [168, 11, 4, 8],
#  422: [82, 11, 8, 8],
#  423: [196, 16, 8, 8],
#  424: [196, 11, 2, 8],
#  425: [196, 11, 2, 7],
#  426: [196, 11, 2, 6],
#  427: [196, 11, 2, 5],
#  428: [196, 11, 2, 4],
#  429: [196, 11, 2, 2],
#  430: [196, 11, 2, 3],
#  431: [17, 11, 8, 8],
#  432: [234, 11, 8, 8],
#  433: [234, 0, 8, 8],
#  434: [234, 11, 6, 8],
#  435: [284, 11, 8, 8],
#  436: [9, 11, 8, 8],
#  437: [86, 11, 8, 8],
#  438: [86, 2, 8, 8],
#  439: [86, 12, 8, 8],
#  440: [183, 11, 8, 8],
#  441: [197, 11, 8, 8],
#  442: [165, 16, 2, 8],
#  443: [165, 11, 2, 8],
#  444: [165, 16, 2, 7],
#  445: [165, 11, 2, 7],
#  446: [165, 16, 2, 6],
#  447: [165, 11, 2, 6],
#  448: [165, 16, 2, 5],
#  449: [165, 11, 2, 5],
#  450: [165, 16, 2, 4],
#  451: [165, 11, 2, 4],
#  452: [165, 16, 2, 2],
#  453: [165, 11, 2, 2],
#  454: [165, 16, 2, 3],
#  455: [165, 11, 2, 3],
#  456: [28, 11, 8, 8],
#  457: [253, 16, 8, 8],
#  458: [253, 11, 8, 8],
#  459: [274, 11, 8, 8],
#  460: [274, 12, 8, 8],
#  461: [99, 11, 8, 8],
#  462: [92, 11, 8, 8],
#  463: [328, 18, 8, 8],
#  464: [25, 11, 8, 8],
#  465: [25, 7, 8, 8],
#  466: [25, 12, 8, 8],
#  467: [25, 11, 2, 8],
#  468: [25, 11, 2, 7],
#  469: [25, 11, 2, 6],
#  470: [25, 11, 2, 5],
#  471: [25, 11, 2, 4],
#  472: [25, 11, 2, 2],
#  473: [25, 11, 2, 3],
#  474: [206, 16, 8, 8],
#  475: [206, 11, 3, 8],
#  476: [206, 11, 3, 0],
#  477: [206, 11, 3, 3],
#  478: [206, 11, 3, 1],
#  479: [206, 11, 7, 8],
#  480: [231, 11, 8, 8],
#  481: [231, 12, 8, 8],
#  482: [193, 11, 8, 8],
#  483: [194, 11, 8, 8],
#  484: [35, 11, 8, 8],
#  485: [126, 11, 8, 8],
#  486: [226, 11, 3, 8],
#  487: [226, 11, 3, 0],
#  488: [226, 11, 3, 3],
#  489: [226, 11, 3, 1],
#  490: [188, 11, 8, 8],
#  491: [311, 16, 8, 8],
#  492: [36, 11, 8, 8],
#  493: [112, 11, 8, 8],
#  494: [20, 11, 2, 8],
#  495: [20, 11, 2, 7],
#  496: [20, 11, 2, 6],
#  497: [20, 11, 2, 5],
#  498: [20, 11, 2, 4],
#  499: [20, 11, 2, 2],
#  500: [20, 11, 2, 3],
#  501: [97, 11, 8, 8],
#  502: [107, 11, 8, 8],
#  503: [259, 11, 8, 8],
#  504: [108, 11, 8, 8],
#  505: [160, 11, 2, 8],
#  506: [160, 11, 2, 7],
#  507: [160, 11, 2, 6],
#  508: [160, 11, 2, 5],
#  509: [160, 11, 2, 4],
#  510: [160, 11, 2, 2],
#  511: [160, 11, 2, 3],
#  512: [160, 11, 3, 8],
#  513: [160, 11, 3, 0],
#  514: [160, 11, 3, 3],
#  515: [160, 11, 3, 1],
#  516: [159, 11, 3, 8],
#  517: [159, 11, 3, 0],
#  518: [159, 11, 3, 3],
#  519: [159, 11, 3, 1],
#  520: [40, 11, 8, 8],
#  521: [277, 11, 2, 8],
#  522: [277, 11, 2, 7],
#  523: [277, 11, 2, 6],
#  524: [277, 11, 2, 5],
#  525: [277, 11, 2, 4],
#  526: [277, 11, 2, 2],
#  527: [277, 11, 2, 3],
#  528: [45, 11, 2, 8],
#  529: [45, 11, 2, 7],
#  530: [45, 11, 2, 6],
#  531: [45, 11, 2, 5],
#  532: [45, 11, 2, 4],
#  533: [45, 11, 2, 2],
#  534: [45, 11, 2, 3],
#  535: [278, 11, 3, 8],
#  536: [278, 11, 3, 0],
#  537: [278, 11, 3, 3],
#  538: [278, 11, 3, 1],
#  539: [201, 11, 3, 8],
#  540: [201, 11, 3, 0],
#  541: [201, 11, 3, 3],
#  542: [201, 11, 3, 1],
#  543: [172, 11, 2, 8],
#  544: [172, 11, 2, 7],
#  545: [172, 11, 2, 6],
#  546: [172, 11, 2, 5],
#  547: [172, 11, 2, 4],
#  548: [172, 11, 2, 2],
#  549: [172, 11, 2, 3],
#  550: [331, 11, 3, 8],
#  551: [331, 11, 3, 0],
#  552: [331, 11, 3, 3],
#  553: [331, 11, 3, 1],
#  554: [291, 11, 2, 8],
#  555: [291, 11, 2, 7],
#  556: [291, 11, 2, 6],
#  557: [291, 11, 2, 5],
#  558: [291, 11, 2, 4],
#  559: [291, 11, 2, 2],
#  560: [291, 11, 2, 3],
#  561: [290, 11, 2, 8],
#  562: [290, 11, 2, 7],
#  563: [290, 11, 2, 6],
#  564: [290, 11, 2, 5],
#  565: [290, 11, 2, 4],
#  566: [290, 11, 2, 2],
#  567: [290, 11, 2, 3],
#  568: [288, 11, 2, 8],
#  569: [288, 11, 2, 7],
#  570: [288, 11, 2, 6],
#  571: [288, 11, 2, 5],
#  572: [288, 11, 2, 4],
#  573: [288, 11, 2, 2],
#  574: [288, 11, 2, 3],
#  575: [146, 11, 8, 8],
#  576: [109, 11, 8, 8],
#  577: [31, 11, 8, 8],
#  578: [310, 11, 3, 8],
#  579: [310, 11, 3, 0],
#  580: [310, 11, 3, 3],
#  581: [310, 11, 3, 1],
#  582: [320, 12, 8, 8],
#  583: [319, 11, 8, 8],
#  584: [319, 16, 3, 8],
#  585: [319, 11, 3, 8],
#  586: [319, 16, 3, 0],
#  587: [319, 11, 3, 0],
#  588: [319, 16, 3, 3],
#  589: [319, 11, 3, 3],
#  590: [319, 16, 3, 1],
#  591: [319, 11, 3, 1],
#  592: [100, 11, 8, 8],
#  593: [106, 11, 8, 8],
#  594: [313, 12, 8, 8],
#  595: [308, 11, 2, 8],
#  596: [308, 11, 2, 7],
#  597: [308, 11, 2, 6],
#  598: [308, 11, 2, 5],
#  599: [308, 11, 2, 4],
#  600: [308, 11, 2, 2],
#  601: [308, 11, 2, 3],
#  602: [307, 11, 2, 8],
#  603: [307, 11, 2, 7],
#  604: [307, 11, 2, 6],
#  605: [307, 11, 2, 5],
#  606: [307, 11, 2, 4],
#  607: [307, 11, 2, 2],
#  608: [307, 11, 2, 3],
#  609: [91, 11, 8, 8],
#  610: [190, 11, 2, 8],
#  611: [190, 11, 2, 7],
#  612: [190, 11, 2, 6],
#  613: [190, 11, 2, 5],
#  614: [190, 11, 2, 4],
#  615: [190, 11, 2, 2],
#  616: [190, 11, 2, 3],
#  617: [286, 11, 2, 8],
#  618: [286, 11, 2, 7],
#  619: [286, 11, 2, 6],
#  620: [286, 11, 2, 5],
#  621: [286, 11, 2, 4],
#  622: [286, 11, 2, 2],
#  623: [286, 11, 2, 3],
#  624: [323, 16, 8, 8],
#  625: [323, 11, 3, 8],
#  626: [323, 11, 3, 0],
#  627: [323, 11, 3, 3],
#  628: [323, 11, 3, 1],
#  629: [323, 11, 7, 8],
#  630: [323, 15, 7, 8],
#  631: [156, 11, 3, 8],
#  632: [156, 11, 3, 0],
#  633: [156, 11, 3, 3],
#  634: [156, 11, 3, 1],
#  635: [252, 11, 3, 8],
#  636: [252, 11, 3, 0],
#  637: [252, 11, 3, 3],
#  638: [252, 11, 3, 1],
#  639: [262, 11, 3, 8],
#  640: [262, 11, 3, 0],
#  641: [262, 11, 3, 3],
#  642: [262, 11, 3, 1],
#  643: [251, 11, 3, 8],
#  644: [251, 11, 3, 0],
#  645: [251, 11, 3, 3],
#  646: [251, 11, 3, 1],
#  647: [265, 11, 3, 8],
#  648: [265, 11, 3, 0],
#  649: [265, 11, 3, 3],
#  650: [265, 11, 3, 1],
#  651: [267, 18, 8, 8],
#  652: [267, 11, 8, 8],
#  653: [267, 12, 8, 8],
#  654: [267, 11, 3, 8],
#  655: [267, 11, 3, 0],
#  656: [267, 11, 3, 3],
#  657: [267, 11, 3, 1],
#  658: [317, 11, 4, 8],
#  659: [177, 11, 4, 8],
#  660: [279, 11, 2, 8],
#  661: [279, 11, 2, 7],
#  662: [279, 11, 2, 6],
#  663: [279, 11, 2, 5],
#  664: [279, 11, 2, 4],
#  665: [279, 11, 2, 2],
#  666: [279, 11, 2, 3],
#  667: [51, 11, 2, 8],
#  668: [51, 11, 2, 7],
#  669: [51, 11, 2, 6],
#  670: [51, 11, 2, 5],
#  671: [51, 11, 2, 4],
#  672: [51, 11, 2, 2],
#  673: [51, 11, 2, 3],
#  674: [50, 11, 2, 8],
#  675: [50, 11, 2, 7],
#  676: [50, 11, 2, 6],
#  677: [50, 11, 2, 5],
#  678: [50, 11, 2, 4],
#  679: [50, 11, 2, 2],
#  680: [50, 11, 2, 3],
#  681: [65, 11, 5, 8],
#  682: [179, 11, 8, 8],
#  683: [227, 11, 8, 8],
#  684: [227, 16, 8, 8],
#  685: [316, 11, 2, 8],
#  686: [316, 11, 2, 7],
#  687: [316, 11, 2, 6],
#  688: [316, 11, 2, 5],
#  689: [316, 11, 2, 4],
#  690: [316, 11, 2, 2],
#  691: [316, 11, 2, 3],
#  692: [316, 11, 7, 8],
#  693: [272, 11, 8, 8],
#  694: [272, 12, 8, 8],
#  695: [272, 11, 3, 8],
#  696: [272, 11, 3, 0],
#  697: [272, 11, 3, 3],
#  698: [272, 11, 3, 1],
#  699: [174, 11, 2, 8],
#  700: [174, 11, 2, 7],
#  701: [174, 11, 2, 6],
#  702: [174, 11, 2, 5],
#  703: [174, 11, 2, 4],
#  704: [174, 11, 2, 2],
#  705: [174, 11, 2, 3],
#  706: [315, 11, 7, 8],
#  707: [47, 11, 8, 8],
#  708: [85, 11, 8, 8],
#  709: [312, 11, 3, 8],
#  710: [312, 11, 3, 0],
#  711: [312, 11, 3, 3],
#  712: [312, 11, 3, 1],
#  713: [187, 11, 2, 8],
#  714: [187, 11, 2, 7],
#  715: [187, 11, 2, 6],
#  716: [187, 11, 2, 5],
#  717: [187, 11, 2, 4],
#  718: [187, 11, 2, 2],
#  719: [187, 11, 2, 3],
#  720: [216, 5, 8, 8],
#  721: [68, 11, 3, 8],
#  722: [68, 11, 3, 0],
#  723: [68, 11, 3, 3],
#  724: [68, 11, 3, 1],
#  725: [46, 11, 8, 8],
#  726: [178, 11, 8, 8],
#  727: [37, 12, 8, 8],
#  728: [74, 11, 7, 8],
#  729: [73, 11, 7, 8],
#  730: [135, 11, 8, 8],
#  731: [138, 11, 8, 8],
#  732: [137, 11, 8, 8],
#  733: [139, 11, 8, 8],
#  734: [136, 11, 8, 8],
#  735: [246, 11, 8, 8],
#  736: [257, 16, 8, 8],
#  737: [257, 11, 2, 8],
#  738: [257, 11, 2, 7],
#  739: [257, 11, 2, 6],
#  740: [257, 11, 2, 5],
#  741: [257, 11, 2, 4],
#  742: [257, 11, 2, 2],
#  743: [257, 11, 2, 3],
#  744: [257, 11, 7, 8],
#  745: [70, 11, 3, 8],
#  746: [70, 11, 3, 0],
#  747: [70, 11, 3, 3],
#  748: [70, 11, 3, 1],
#  749: [90, 11, 8, 8],
#  750: [169, 11, 8, 8],
#  751: [56, 11, 7, 8],
#  752: [55, 11, 7, 8],
#  753: [209, 11, 8, 8],
#  754: [14, 11, 2, 8],
#  755: [14, 11, 2, 7],
#  756: [14, 11, 2, 6],
#  757: [14, 11, 2, 5],
#  758: [14, 11, 2, 4],
#  759: [14, 11, 2, 2],
#  760: [14, 11, 2, 3],
#  761: [258, 11, 2, 8],
#  762: [258, 11, 2, 7],
#  763: [258, 11, 2, 6],
#  764: [258, 11, 2, 5],
#  765: [258, 11, 2, 4],
#  766: [258, 11, 2, 2],
#  767: [258, 11, 2, 3],
#  768: [39, 11, 8, 8],
#  769: [39, 11, 2, 8],
#  770: [39, 11, 2, 7],
#  771: [39, 11, 2, 6],
#  772: [39, 11, 2, 5],
#  773: [39, 11, 2, 4],
#  774: [39, 11, 2, 2],
#  775: [39, 11, 2, 3],
#  776: [155, 11, 2, 8],
#  777: [155, 11, 2, 7],
#  778: [155, 11, 2, 6],
#  779: [155, 11, 2, 5],
#  780: [155, 11, 2, 4],
#  781: [155, 11, 2, 2],
#  782: [155, 11, 2, 3],
#  783: [224, 11, 8, 8],
#  784: [224, 11, 4, 8],
#  785: [301, 11, 8, 8],
#  786: [295, 11, 4, 8],
#  787: [296, 11, 4, 8],
#  788: [297, 11, 4, 8],
#  789: [264, 16, 8, 8],
#  790: [23, 11, 2, 8],
#  791: [23, 11, 2, 7],
#  792: [23, 11, 2, 6],
#  793: [23, 11, 2, 5],
#  794: [23, 11, 2, 4],
#  795: [23, 11, 2, 2],
#  796: [23, 11, 2, 3],
#  797: [327, 11, 2, 8],
#  798: [327, 11, 2, 7],
#  799: [327, 11, 2, 6],
#  800: [327, 11, 2, 5],
#  801: [327, 11, 2, 4],
#  802: [327, 11, 2, 2],
#  803: [327, 11, 2, 3],
#  804: [129, 11, 8, 8],
#  805: [11, 11, 8, 8],
#  806: [205, 11, 2, 8],
#  807: [205, 11, 2, 7],
#  808: [205, 11, 2, 6],
#  809: [205, 11, 2, 5],
#  810: [205, 11, 2, 4],
#  811: [205, 11, 2, 2],
#  812: [205, 11, 2, 3],
#  813: [299, 11, 2, 8],
#  814: [299, 11, 2, 7],
#  815: [299, 11, 2, 6],
#  816: [299, 11, 2, 5],
#  817: [299, 11, 2, 4],
#  818: [299, 11, 2, 2],
#  819: [299, 11, 2, 3],
#  820: [67, 11, 8, 8],
#  821: [208, 2, 8, 8],
#  822: [266, 11, 2, 8],
#  823: [266, 11, 2, 7],
#  824: [266, 11, 2, 6],
#  825: [266, 11, 2, 5],
#  826: [266, 11, 2, 4],
#  827: [266, 11, 2, 2],
#  828: [266, 11, 2, 3],
#  829: [152, 11, 7, 8],
#  830: [338, 11, 3, 8],
#  831: [338, 11, 3, 0],
#  832: [338, 11, 3, 3],
#  833: [338, 11, 3, 1],
#  834: [167, 11, 2, 8],
#  835: [167, 11, 2, 7],
#  836: [167, 11, 2, 6],
#  837: [167, 11, 2, 5],
#  838: [167, 11, 2, 4],
#  839: [167, 11, 2, 2],
#  840: [167, 11, 2, 3],
#  841: [80, 11, 3, 8],
#  842: [80, 11, 3, 0],
#  843: [80, 11, 3, 3],
#  844: [80, 11, 3, 1],
#  845: [325, 11, 3, 8],
#  846: [325, 11, 3, 0],
#  847: [325, 11, 3, 3],
#  848: [325, 11, 3, 1],
#  849: [117, 11, 8, 8],
#  850: [292, 11, 8, 8],
#  851: [292, 16, 8, 8],
#  852: [30, 11, 8, 8],
#  853: [29, 11, 8, 8],
#  854: [27, 11, 8, 8],
#  855: [218, 11, 8, 8],
#  856: [303, 11, 8, 8],
#  857: [66, 11, 8, 8],
#  858: [242, 11, 8, 8],
#  859: [207, 11, 8, 8],
#  860: [207, 11, 2, 8],
#  861: [207, 11, 2, 7],
#  862: [207, 11, 2, 6],
#  863: [207, 11, 2, 5],
#  864: [207, 11, 2, 4],
#  865: [207, 11, 2, 2],
#  866: [207, 11, 2, 3],
#  867: [0, 11, 4, 8],
#  868: [220, 11, 8, 8],
#  869: [171, 11, 2, 8],
#  870: [171, 11, 2, 7],
#  871: [171, 11, 2, 6],
#  872: [171, 11, 2, 5],
#  873: [171, 11, 2, 4],
#  874: [171, 11, 2, 2],
#  875: [171, 11, 2, 3],
#  876: [171, 11, 3, 8],
#  877: [171, 11, 3, 0],
#  878: [171, 11, 3, 3],
#  879: [171, 11, 3, 1],
#  880: [333, 11, 8, 8],
#  881: [240, 11, 8, 8],
#  882: [232, 16, 8, 8],
#  883: [239, 16, 8, 8],
#  884: [219, 2, 7, 8],
#  885: [321, 2, 7, 8],
#  886: [166, 11, 2, 8],
#  887: [166, 11, 2, 7],
#  888: [166, 11, 2, 6],
#  889: [166, 11, 2, 5],
#  890: [166, 11, 2, 4],
#  891: [166, 11, 2, 2],
#  892: [166, 11, 2, 3],
#  893: [149, 11, 3, 8],
#  894: [149, 11, 3, 0],
#  895: [149, 11, 3, 3],
#  896: [149, 11, 3, 1],
#  897: [195, 11, 8, 8],
#  898: [271, 11, 8, 8],
#  899: [103, 11, 8, 8],
#  900: [95, 11, 8, 8],
#  901: [96, 11, 8, 8],
#  902: [270, 11, 2, 8],
#  903: [270, 11, 2, 7],
#  904: [270, 11, 2, 6],
#  905: [270, 11, 2, 5],
#  906: [270, 11, 2, 4],
#  907: [270, 11, 2, 2],
#  908: [270, 11, 2, 3],
#  909: [173, 16, 8, 8],
#  910: [154, 11, 2, 8],
#  911: [154, 11, 2, 7],
#  912: [154, 11, 2, 6],
#  913: [154, 11, 2, 5],
#  914: [154, 11, 2, 4],
#  915: [154, 11, 2, 2],
#  916: [154, 11, 2, 3],
#  917: [233, 11, 8, 8],
#  918: [198, 11, 8, 8],
#  919: [249, 11, 8, 8],
#  920: [48, 12, 2, 8],
#  921: [48, 16, 2, 8],
#  922: [48, 12, 2, 7],
#  923: [48, 16, 2, 7],
#  924: [48, 12, 2, 6],
#  925: [48, 16, 2, 6],
#  926: [48, 12, 2, 5],
#  927: [48, 16, 2, 5],
#  928: [48, 12, 2, 4],
#  929: [48, 16, 2, 4],
#  930: [48, 12, 2, 2],
#  931: [48, 16, 2, 2],
#  932: [48, 12, 2, 3],
#  933: [48, 16, 2, 3],
#  934: [41, 12, 8, 8],
#  935: [132, 11, 2, 8],
#  936: [132, 11, 2, 7],
#  937: [132, 11, 2, 6],
#  938: [132, 11, 2, 5],
#  939: [132, 11, 2, 4],
#  940: [132, 11, 2, 2],
#  941: [132, 11, 2, 3],
#  942: [33, 11, 8, 8],
#  943: [33, 12, 2, 8],
#  944: [33, 12, 2, 7],
#  945: [33, 12, 2, 6],
#  946: [33, 12, 2, 5],
#  947: [33, 12, 2, 4],
#  948: [33, 12, 2, 2],
#  949: [33, 12, 2, 3],
#  950: [87, 11, 8, 8],
#  951: [287, 11, 2, 8],
#  952: [287, 4, 2, 8],
#  953: [287, 3, 2, 8],
#  954: [287, 11, 2, 7],
#  955: [287, 4, 2, 7],
#  956: [287, 3, 2, 7],
#  957: [287, 11, 2, 6],
#  958: [287, 4, 2, 6],
#  959: [287, 3, 2, 6],
#  960: [287, 11, 2, 5],
#  961: [287, 4, 2, 5],
#  962: [287, 3, 2, 5],
#  963: [287, 11, 2, 4],
#  964: [287, 4, 2, 4],
#  965: [287, 3, 2, 4],
#  966: [287, 11, 2, 2],
#  967: [287, 4, 2, 2],
#  968: [287, 3, 2, 2],
#  969: [287, 11, 2, 3],
#  970: [287, 4, 2, 3],
#  971: [287, 3, 2, 3],
#  972: [287, 11, 3, 8],
#  973: [287, 11, 3, 0],
#  974: [287, 11, 3, 3],
#  975: [287, 11, 3, 1],
#  976: [200, 11, 2, 8],
#  977: [200, 11, 2, 7],
#  978: [200, 11, 2, 6],
#  979: [200, 11, 2, 5],
#  980: [200, 11, 2, 4],
#  981: [200, 11, 2, 2],
#  982: [200, 11, 2, 3],
#  983: [199, 11, 2, 8],
#  984: [199, 11, 2, 7],
#  985: [199, 11, 2, 6],
#  986: [199, 11, 2, 5],
#  987: [199, 11, 2, 4],
#  988: [199, 11, 2, 2],
#  989: [199, 11, 2, 3],
#  990: [324, 11, 2, 8],
#  991: [324, 11, 2, 7],
#  992: [324, 11, 2, 6],
#  993: [324, 11, 2, 5],
#  994: [324, 11, 2, 4],
#  995: [324, 11, 2, 2],
#  996: [324, 11, 2, 3],
#  997: [225, 11, 2, 8],
#  998: [225, 11, 2, 7],
#  999: [225, 11, 2, 6],
#  ...}

# %% [markdown]
# # Reverse Design

# %%
for column in X[best_features].columns:
    print(f'column:{column},max:{max(X[best_features][column])}')
# Out:
# column:Cell_architecture,max:1
# column:Substrate_stack_sequence,max:1
# column:ETL_stack_sequence,max:19
# column:ETL_additives_compounds,max:129
# column:ETL_deposition_procedure,max:19
# column:Perovskite_composition_none_stoichiometry_components_in_excess,max:12
# column:Perovskite_additives_compounds,max:340
# column:Perovskite_deposition_procedure,max:19
# column:DMF_DMSO,max:1.0
# column:Perovskite_deposition_quenching_media,max:9
# column:HTL_stack_sequence,max:19
# column:HTL_additives_compounds,max:120
# column:Backcontact_stack_sequence,max:8
# column:Backcontact_thickness_list,max:550.0
# column:Perovskite_deposition_solvents_IPA,max:1
# column:Perovskite_deposition_thermal_annealing,max:455

# %% [markdown]
# ## nip

# %%
class Error(Exception):
    pass
prob_params = []
prob = []

def ft_optuna_objective(trial):  
    try:
        ETL = trial.suggest_int("ETL", 0, 167, 1)
        PVK = trial.suggest_int("PVK", 0, 1386, 1)
        HTL = trial.suggest_int("HTL", 0, 87, 1)
        ETL_stack_sequence = etl_nip_dic[ETL][0]
        ETL_additives_compounds = etl_nip_dic[ETL][1]
        ETL_deposition_procedure = etl_nip_dic[ETL][2]
        Perovskite_additives_compounds = pvkm_list_dic[PVK][0]
        Perovskite_deposition_procedure = pvkm_list_dic[PVK][1]
        Perovskite_deposition_quenching_media = pvkm_list_dic[PVK][2]
        HTL_stack_sequence = htl_nip_dic[HTL][0]
        HTL_additives_compounds = htl_nip_dic[HTL][1]
        
        Cell_architecture = 0   # nip
        Substrate_stack_sequence = trial.suggest_int("Substrate_stack_sequence", 0, 1, 1)
        Perovskite_composition_none_stoichiometry_components_in_excess = trial.suggest_int("Perovskite_composition_none_stoichiometry_components_in_excess", 0, 12, 1)
        DMF_DMS0 = trial.suggest_float("DMF_DMS0", 0, 1)
        Backcontact_stack_sequence = trial.suggest_int("Backcontact_stack_sequence", 0, 8, 1)
        Backcontact_thickness_list = trial.suggest_float("Backcontact_thickness_list", 0, 550)
        Perovskite_deposition_solvents_IPA = trial.suggest_int("Perovskite_deposition_solvents_IPA", 0, 1, 1)
        Perovskite_deposition_thermal_annealing = trial.suggest_int("Perovskite_deposition_thermal_annealing", 0, 455, 1)
        
        params = {
            'Cell_architecture':Cell_architecture,
            'Substrate_stack_sequence':Substrate_stack_sequence,
            'ETL_stack_sequence':ETL_stack_sequence,
            'ETL_additives_compounds':ETL_additives_compounds,
            'ETL_deposition_procedure':ETL_deposition_procedure,
            'Perovskite_composition_none_stoichiometry_components_in_excess':Perovskite_composition_none_stoichiometry_components_in_excess,
            'Perovskite_additives_compounds':Perovskite_additives_compounds,
            'Perovskite_deposition_procedure':Perovskite_deposition_procedure,
            'DMF_DMS0':DMF_DMS0,
            'Perovskite_deposition_quenching_media':Perovskite_deposition_quenching_media,
            'HTL_stack_sequence':HTL_stack_sequence,
            'HTL_additives_compounds':HTL_additives_compounds,
            'Backcontact_stack_sequence':Backcontact_stack_sequence,
            'Backcontact_thickness_list':Backcontact_thickness_list,
            'Perovskite_deposition_solvents_IPA':Perovskite_deposition_solvents_IPA,
            'Perovskite_deposition_thermal_annealing':Perovskite_deposition_thermal_annealing
        }
        
    except Error:
        raise optuna.TrialPruned()     

    params_list = pd.Series(params).values.reshape(1,-1)
    params_list = pd.DataFrame(params_list, columns=X_fit.columns)
    y_prob = voting_clf.predict_proba(params_list)[:,1]
    data_rf_none = pd.DataFrame()

    if y_prob > 0.9:
        prob.append(y_prob)
        prob_params.append(params_list)
    return y_prob

# %%
def optimizer_optuna(n_trials, algo):

    if algo == "TPE":
        algo = optuna.samplers.TPESampler(n_startup_trials = 10, n_ei_candidates = 24)
    elif algo == "GP":
        from optuna.integration import SkoptSampler
        import skopt
        algo = SkoptSampler(skopt_kwargs={'base_estimator':'GP',
                                          'n_initial_points':10, 
                                          'acq_func':'EI'} 
                           )

    study = optuna.create_study(sampler = algo 
                                , direction="maximize" 
                               )
    
    study.optimize(ft_optuna_objective 
                   , n_trials=n_trials 
                   , show_progress_bar=True 
                  )
    
    print("\n","\n","best params: ", study.best_trial.params,
          "\n","\n","best score: ", study.best_trial.values,
          "\n")

    
    return study.best_trial.params, study.best_trial.values

# %%
optuna.logging.set_verbosity(optuna.logging.ERROR) 
best_nip_params, best_nip_prob = optimizer_optuna(2000,"TPE")
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
#
#  best params:  {'ETL': 26, 'PVK': 645, 'HTL': 62, 'Substrate_stack_sequence': 0, 'Perovskite_composition_none_stoichiometry_components_in_excess': 9, 'DMF_DMS0': 0.9706586128458718, 'Backcontact_stack_sequence': 1, 'Backcontact_thickness_list': 114.37485070686964, 'Perovskite_deposition_solvents_IPA': 0, 'Perovskite_deposition_thermal_annealing': 13}
#
#  best score:  [0.9707129069110587]

# %%
col_nip = ['Cell_architecture', 'Substrate_stack_sequence', 'ETL_stack_sequence',
       'ETL_additives_compounds', 'ETL_deposition_procedure',
       'Perovskite_composition_none_stoichiometry_components_in_excess',
       'Perovskite_additives_compounds', 'Perovskite_deposition_procedure',
       'DMF_DMSO', 'Perovskite_deposition_quenching_media',
       'HTL_stack_sequence', 'HTL_additives_compounds',
       'Backcontact_stack_sequence', 'Backcontact_thickness_list',
       'Perovskite_deposition_solvents_IPA',
       'Perovskite_deposition_thermal_annealing','prob']

# %%
if len(prob_params) > 0:
    df_prob_params = pd.concat(prob_params, ignore_index=True)
else:
    print("No data in prob_params.")
    
prob_params = pd.DataFrame(df_prob_params)
prob = [item[0] for item in prob]
prob_params['prob']=prob
prob_params.columns = col_nip
for column in prob_params.keys():
    dic_name = column + "_dic"
    if dic_name in globals():
        prob_params[column] = [globals()[dic_name].get(value,value) for value in prob_params[column]]
    else:
        continue
prob_params
# Out:
#     Cell_architecture Substrate_stack_sequence ETL_stack_sequence  \
# 0                 nip                SLG | FTO             TiO2-c
# 1                 nip                SLG | ITO             TiO2-c
# 2                 nip                SLG | ITO             TiO2-c
# 3                 nip                SLG | ITO             TiO2-c
# 4                 nip                SLG | FTO             TiO2-c
# ..                ...                      ...                ...
# 279               nip                SLG | FTO             SnO2-c
# 280               nip                SLG | FTO            SnO2-np
# 281               nip                SLG | FTO             SnO2-c
# 282               nip                SLG | FTO            SnO2-np
# 283               nip                SLG | FTO   TiO2-c | PCBM-60
#
#     ETL_additives_compounds ETL_deposition_procedure  \
# 0           rGraphene oxide             Spin-coating
# 1                        Zn             Spin-coating
# 2                  CF3NaO2S             Spin-coating
# 3                      TOPD             Spin-coating
# 4                        Zn             Spin-coating
# ..                      ...                      ...
# 279               Bi2O2S-np             Spin-coating
# 280                      Zr             Spin-coating
# 281                   Ti3C2             Spin-coating
# 282                      Zr             Spin-coating
# 283                 Undoped       CBD | Spin-coating
#
#     Perovskite_composition_none_stoichiometry_components_in_excess  \
# 0                                          PbI2; PbBr2
# 1                                          PbI2; PbBr2
# 2                                          PbI2; PbBr2
# 3                                          PbI2; PbBr2
# 4                                          PbI2; PbBr2
# ..                                                 ...
# 279                                              NH4Cl
# 280                                              NH4Cl
# 281                                              NH4Cl
# 282                                              NH4Cl
# 283                                                MAI
#
#     Perovskite_additives_compounds Perovskite_deposition_procedure  DMF_DMSO  \
# 0                            PbAc2                    Spin-coating  0.413749
# 1                         Caffeine                    Spin-coating  0.594520
# 2                             TFBA                    Spin-coating  0.789716
# 3                           PbSCN2                    Spin-coating  0.968268
# 4                               EC                    Spin-coating  0.936300
# ..                             ...                             ...       ...
# 279                        Cl; DPE             Spin-coating >> CBD  0.796446
# 280                             Cs                    Spin-coating  0.839664
# 281                           ITIC                    Spin-coating  0.859713
# 282                  ITIC; PCBM-60                    Spin-coating  0.806611
# 283                          DCL97                    Spin-coating  0.793530
#
#     Perovskite_deposition_quenching_media HTL_stack_sequence  \
# 0                           Diethyl ether       Spiro-MeOTAD
# 1                           Diethyl ether       Spiro-MeOTAD
# 2                           Diethyl ether       Spiro-MeOTAD
# 3                           Diethyl ether       Spiro-MeOTAD
# 4                           Diethyl ether       Spiro-MeOTAD
# ..                                    ...                ...
# 279                         Chlorobenzene               PTAA
# 280                         Diethyl ether               PTAA
# 281                         Chlorobenzene               PTAA
# 282                         Chlorobenzene               PTAA
# 283                         Chlorobenzene               PTAA
#
#        HTL_additives_compounds Backcontact_stack_sequence  \
# 0                 Li-TFSI; TPB                  MoO3 | Al
# 1            JQ3; Li-TFSI; TBP                  MoO3 | Al
# 2                 Li-TFSI; TBP                  MoO3 | Al
# 3                 Li-TFSI; TPB                  MoO3 | Al
# 4            JQ1; Li-TFSI; TBP                  MoO3 | Al
# ..                         ...                        ...
# 279                       TPFB                         Ag
# 280                    Li-TFSI                       AgAl
# 281  Li-TFSI; Polystyrene; TBP                       AgAl
# 282                        LAD                       AgAl
# 283                         O2                       AgAl
#
#      Backcontact_thickness_list  Perovskite_deposition_solvents_IPA  \
# 0                    103.837946                                   0
# 1                     94.324074                                   0
# 2                    423.643550                                   0
# 3                    200.480113                                   0
# 4                    453.624393                                   0
# ..                          ...                                 ...
# 279                  154.966131                                   0
# 280                  163.357421                                   0
# 281                  223.421049                                   0
# 282                  402.340067                                   0
# 283                  368.555878                                   0
#
#     Perovskite_deposition_thermal_annealing      prob
# 0                                100.0-70.0  0.931267
# 1                       100; 100-10.0; 60.0  0.903249
# 2                               100.0-100.0  0.918312
# 3                   100.0; 120.0-90.0; 15.0  0.902496
# 4                               100.0-600.0  0.939985
# ..                                      ...       ...
# 279                       25; 60-20.0; 40.0  0.903983
# 280                               70.0-20.0  0.944395
# 281                                60.0-2.0  0.952053
# 282                      150; 100-5.0; 20.0  0.945167
# 283                     65.0; 100-1.0; 10.0  0.935325
#
# [284 rows x 17 columns]

# %%
prob_params_nip = prob_params.sort_values(by='prob',ascending=False).reset_index(drop=True)
prob_params_nip.head(20)
# Out:
#    Cell_architecture Substrate_stack_sequence ETL_stack_sequence  \
# 0                nip                SLG | FTO             TiO2-c
# 1                nip                SLG | FTO             SnO2-c
# 2                nip                SLG | FTO             TiO2-c
# 3                nip                SLG | FTO             SnO2-c
# 4                nip                SLG | FTO             SnO2-c
# 5                nip                SLG | FTO             TiO2-c
# 6                nip                SLG | FTO             SnO2-c
# 7                nip                SLG | FTO   TiO2-c | PCBM-60
# 8                nip                SLG | FTO             SnO2-c
# 9                nip                SLG | FTO             SnO2-c
# 10               nip                SLG | FTO             SnO2-c
# 11               nip                SLG | FTO   TiO2-c | PCBM-60
# 12               nip                SLG | FTO             TiO2-c
# 13               nip                SLG | FTO   TiO2-c | PCBM-60
# 14               nip                SLG | FTO             SnO2-c
# 15               nip                SLG | FTO            SnO2-np
# 16               nip                SLG | FTO             SnO2-c
# 17               nip                SLG | FTO             TiO2-c
# 18               nip                SLG | FTO             TiO2-c
# 19               nip                SLG | FTO             TiO2-c
#
#                 ETL_additives_compounds     ETL_deposition_procedure  \
# 0                                    Zn                 Spin-coating
# 1   SnCl2; MercaptoPropionic acid; Urea                 Spin-coating
# 2                                  TOPD  Spin-coating | Spin-coating
# 3                               Undoped                  Evaporation
# 4                               Undoped                 Spin-coating
# 5                Galliumnitrate聽hydrate                 Spin-coating
# 6                                 Ti3C2                 Spin-coating
# 7                               Undoped  Spin-coating | Spin-coating
# 8                                    La                 Spin-coating
# 9   SnCl2; MercaptoPropionic acid; Urea                 Spin-coating
# 10                                   La                 Spin-coating
# 11                              Undoped   Spin-coating | Evaporation
# 12                              Undoped                  Evaporation
# 13                              Undoped  Spin-coating | Spin-coating
# 14                                Ti3C2                 Spin-coating
# 15                                   Zr                 Spin-coating
# 16                              Undoped                 Spin-coating
# 17                              Undoped           E-beam evaporation
# 18                                   Zn                 Spin-coating
# 19                                 TOPD                 Spin-coating
#
#    Perovskite_composition_none_stoichiometry_components_in_excess  \
# 0                                                PbI2
# 1                                               NH4Cl
# 2                                                PbI2
# 3                                               NH4Cl
# 4                                                  Pb
# 5                                                PbI2
# 6                                               NH4Cl
# 7                                               NH4Cl
# 8                                               NH4Cl
# 9                                               NH4Cl
# 10                                               PbI2
# 11                                              NH4Cl
# 12                                               PbI2
# 13                                               PbI2
# 14                                                 Pb
# 15                                               PbI2
# 16                                              NH4Cl
# 17                                               PbI2
# 18                                               PbI2
# 19                                               PbI2
#
#    Perovskite_additives_compounds Perovskite_deposition_procedure  DMF_DMSO  \
# 0                             PAA                    Spin-coating  0.970659
# 1                             DMI                    Spin-coating  0.766414
# 2                              PU                    Spin-coating  0.972307
# 3                              Rb                    Spin-coating  0.766852
# 4                            DPSI                    Spin-coating  0.798483
# 5                             PAA                    Spin-coating  0.973323
# 6                         DA2PbI4                    Spin-coating  0.877795
# 7                            E2CA                    Spin-coating  0.743396
# 8                           HATNA                    Spin-coating  0.710715
# 9                             PMA                    Spin-coating  0.884399
# 10                            TMS                    Spin-coating  0.709807
# 11                           E2CA                    Spin-coating  0.805568
# 12                            PPC                    Spin-coating  0.970743
# 13                           SQ45                    Spin-coating  0.771972
# 14                             Rb                    Spin-coating  0.785837
# 15                            PVA                    Spin-coating  0.758890
# 16                           E2CA                    Spin-coating  0.760130
# 17                            PAA                    Spin-coating  0.964999
# 18                            TMS                    Spin-coating  0.973831
# 19                      Carbon-np                    Spin-coating  0.910118
#
#    Perovskite_deposition_quenching_media HTL_stack_sequence  \
# 0                          Diethyl ether               PTAA
# 1                          Diethyl ether               PTAA
# 2                          Diethyl ether               PTAA
# 3                          Diethyl ether               PTAA
# 4                                Toluene               PTAA
# 5                          Diethyl ether               PTAA
# 6                          Chlorobenzene               PTAA
# 7                          Chlorobenzene               PTAA
# 8                          Diethyl ether               PTAA
# 9                          Diethyl ether               PTAA
# 10                         Diethyl ether               PTAA
# 11                         Chlorobenzene               PTAA
# 12                         Diethyl ether               PTAA
# 13                         Ethyl acetate               PTAA
# 14                         Chlorobenzene               PTAA
# 15                         Chlorobenzene               PTAA
# 16                         Chlorobenzene               PTAA
# 17                         Diethyl ether               PTAA
# 18                         Diethyl ether               PTAA
# 19                               Toluene               PTAA
#
#       HTL_additives_compounds Backcontact_stack_sequence  \
# 0                          O2                       AgAl
# 1                     Li-TFSI                       AgAl
# 2                          O2                       AgAl
# 3   Li-TFSI; Polystyrene; TBP                         Ag
# 4                          O2                       AgAl
# 5                          O2                       AgAl
# 6                         LAD                       AgAl
# 7                         LAD                       AgAl
# 8                     Li-TFSI                         Ag
# 9   Li-TFSI; Polystyrene; TBP                       AgAl
# 10  Li-TFSI; Polystyrene; TBP                       AgAl
# 11                        LAD                         Ag
# 12                        LAD                       AgAl
# 13                        LAD                       AgAl
# 14                    Li-TFSI                         Al
# 15                        LAD                       AgAl
# 16                    Li-TFSI                         Ag
# 17                        LAD                       AgAl
# 18                    Li-TFSI                       AgAl
# 19  Li-TFSI; Polystyrene; TBP                       AgAl
#
#     Backcontact_thickness_list  Perovskite_deposition_solvents_IPA  \
# 0                   114.374851                                   0
# 1                   317.410626                                   0
# 2                   136.427656                                   0
# 3                   427.409895                                   0
# 4                   365.711408                                   0
# 5                   118.635581                                   0
# 6                   283.109012                                   0
# 7                   378.695160                                   0
# 8                   404.397925                                   0
# 9                   164.321683                                   0
# 10                  331.960139                                   0
# 11                  400.471864                                   0
# 12                  151.912902                                   0
# 13                  334.202567                                   0
# 14                  313.881951                                   0
# 15                  338.195768                                   0
# 16                  314.481885                                   0
# 17                  153.931335                                   0
# 18                  141.718037                                   0
# 19                   86.286292                                   0
#
#    Perovskite_deposition_thermal_annealing      prob
# 0                              100.0-120.0  0.970713
# 1                               100.0-50.0  0.966778
# 2                               100.0-15.0  0.963339
# 3                               100.0-30.0  0.962446
# 4                              100.0-240.0  0.961790
# 5                              100.0-100.0  0.961558
# 6                     65.0; 100.0-2.0; 4.0  0.961545
# 7                              100.0-240.0  0.961025
# 8                              100.0-150.0  0.959123
# 9                    60.0; 100.0-5.0; 10.0  0.958981
# 10                               100.0-2.0  0.958677
# 11                              100.0-15.0  0.958219
# 12                             100.0-100.0  0.957486
# 13                               100.0-3.0  0.957476
# 14                              100.0-35.0  0.957265
# 15                              100.0-12.0  0.957075
# 16                              100.0-15.0  0.957009
# 17                              100.0-15.0  0.956914
# 18                              100.0-30.0  0.956763
# 19                               100.0-7.0  0.956511

# %% [markdown]
# ## pin

# %%
class Error(Exception):
    pass
prob_params = []
prob = []
def ft_optuna_objective(trial):  
    try:
        ETL = trial.suggest_int("ETL", 0, 51, 1)
        PVK = trial.suggest_int("PVK", 0, 1386, 1)
        HTL = trial.suggest_int("HTL", 0, 81, 1)
        ETL_stack_sequence = etl_pin_dic[ETL][0]
        ETL_additives_compounds = etl_pin_dic[ETL][1]
        ETL_deposition_procedure = etl_pin_dic[ETL][2]
        Perovskite_additives_compounds = pvkm_list_dic[PVK][0]
        Perovskite_deposition_procedure = pvkm_list_dic[PVK][1]
        Perovskite_deposition_quenching_media = pvkm_list_dic[PVK][2]
        HTL_stack_sequence = htl_pin_dic[HTL][0]
        HTL_additives_compounds = htl_pin_dic[HTL][1]
        
        Cell_architecture = 1   # pin
        Substrate_stack_sequence = trial.suggest_int("Substrate_stack_sequence", 0, 1, 1)
        Perovskite_composition_none_stoichiometry_components_in_excess = trial.suggest_int("Perovskite_composition_none_stoichiometry_components_in_excess", 0, 12, 1)
        DMF_DMS0 = trial.suggest_float("DMF_DMS0", 0, 1)
        Backcontact_stack_sequence = trial.suggest_int("Backcontact_stack_sequence", 0, 8, 1)
        Backcontact_thickness_list = trial.suggest_float("Backcontact_thickness_list", 0, 550)
        Perovskite_deposition_solvents_IPA = trial.suggest_int("Perovskite_deposition_solvents_IPA", 0, 1, 1)
        Perovskite_deposition_thermal_annealing = trial.suggest_int("Perovskite_deposition_thermal_annealing", 0, 455, 1)
        
        params = {
            'Cell_architecture':Cell_architecture,
            'Substrate_stack_sequence':Substrate_stack_sequence,
            'ETL_stack_sequence':ETL_stack_sequence,
            'ETL_additives_compounds':ETL_additives_compounds,
            'ETL_deposition_procedure':ETL_deposition_procedure,
            'Perovskite_composition_none_stoichiometry_components_in_excess':Perovskite_composition_none_stoichiometry_components_in_excess,
            'Perovskite_additives_compounds':Perovskite_additives_compounds,
            'Perovskite_deposition_procedure':Perovskite_deposition_procedure,
            'DMF_DMS0':DMF_DMS0,
            'Perovskite_deposition_quenching_media':Perovskite_deposition_quenching_media,
            'HTL_stack_sequence':HTL_stack_sequence,
            'HTL_additives_compounds':HTL_additives_compounds,
            'Backcontact_stack_sequence':Backcontact_stack_sequence,
            'Backcontact_thickness_list':Backcontact_thickness_list,
            'Perovskite_deposition_solvents_IPA':Perovskite_deposition_solvents_IPA,
            'Perovskite_deposition_thermal_annealing':Perovskite_deposition_thermal_annealing
        }
        
    except Error:
        raise optuna.TrialPruned()     

    params_list = pd.Series(params).values.reshape(1,-1)
    params_list = pd.DataFrame(params_list, columns=X_fit.columns)
    y_prob = voting_clf.predict_proba(params_list)[:,1]
    data_rf_none = pd.DataFrame()

    if y_prob > 0.9:
        prob.append(y_prob)
        prob_params.append(params_list)
    return y_prob

# %%
def optimizer_optuna(n_trials, algo):

    if algo == "TPE":
        algo = optuna.samplers.TPESampler(n_startup_trials = 10, n_ei_candidates = 24)
    elif algo == "GP":
        from optuna.integration import SkoptSampler
        import skopt
        algo = SkoptSampler(skopt_kwargs={'base_estimator':'GP',
                                          'n_initial_points':10, 
                                          'acq_func':'EI'} 
                           )

    study = optuna.create_study(sampler = algo 
                                , direction="maximize" 
                               )

    study.optimize(ft_optuna_objective 
                   , n_trials=n_trials 
                   , show_progress_bar=True 
                  )

    print("\n","\n","best params: ", study.best_trial.params,
          "\n","\n","best score: ", study.best_trial.values,
          "\n")

    
    return study.best_trial.params, study.best_trial.values

# %%
optuna.logging.set_verbosity(optuna.logging.ERROR) 
best_pin_params, best_pin_prob = optimizer_optuna(2000,"TPE")
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
#
#  best params:  {'ETL': 35, 'PVK': 1092, 'HTL': 3, 'Substrate_stack_sequence': 1, 'Perovskite_composition_none_stoichiometry_components_in_excess': 11, 'DMF_DMS0': 0.7524417934134233, 'Backcontact_stack_sequence': 1, 'Backcontact_thickness_list': 95.52005388477407, 'Perovskite_deposition_solvents_IPA': 0, 'Perovskite_deposition_thermal_annealing': 269}
#
#  best score:  [0.9745784414834437]

# %%
col_pin = ['Cell_architecture', 'Substrate_stack_sequence', 'ETL_stack_sequence',
       'ETL_additives_compounds', 'ETL_deposition_procedure',
       'Perovskite_composition_none_stoichiometry_components_in_excess',
       'Perovskite_additives_compounds', 'Perovskite_deposition_procedure',
       'DMF_DMSO', 'Perovskite_deposition_quenching_media',
       'HTL_stack_sequence', 'HTL_additives_compounds',
       'Backcontact_stack_sequence', 'Backcontact_thickness_list',
       'Perovskite_deposition_solvents_IPA',
       'Perovskite_deposition_thermal_annealing','prob']

# %%
if len(prob_params) > 0:
    df_prob_params = pd.concat(prob_params, ignore_index=True)
else:
    print("No data in prob_params.")
    
prob_params = pd.DataFrame(df_prob_params)
prob = [item[0] for item in prob]
prob_params['prob']=prob
prob_params.columns = col_pin
for column in prob_params.keys():
    dic_name = column + "_dic"
    if dic_name in globals():
        prob_params[column] = [globals()[dic_name].get(value,value) for value in prob_params[column]]
    else:
        continue
prob_params
# Out:
#     Cell_architecture Substrate_stack_sequence   ETL_stack_sequence  \
# 0                 pin                SLG | ITO        PCBM-60 | BCP
# 1                 pin                SLG | ITO     PCBM-60 | ZnO-np
# 2                 pin                SLG | ITO    PCBM-60 | bis-C60
# 3                 pin                SLG | ITO        PCBM-60 | LiF
# 4                 pin                SLG | ITO    PCBM-60 | bis-C60
# ..                ...                      ...                  ...
# 400               pin                SLG | ITO            C60 | BCP
# 401               pin                SLG | ITO  PCBM-60 | C60 | BCP
# 402               pin                SLG | ITO        PCBM-60 | LiF
# 403               pin                SLG | ITO  PCBM-60 | C60 | BCP
# 404               pin                SLG | ITO  PCBM-60 | C60 | BCP
#
#     ETL_additives_compounds                  ETL_deposition_procedure  \
# 0                    DMOAP                Spin-coating | Spin-coating
# 1                   Undoped               Spin-coating | Spin-coating
# 2                   Undoped               Spin-coating | Spin-coating
# 3                   Undoped                Spin-coating | Evaporation
# 4                   Undoped               Spin-coating | Spin-coating
# ..                      ...                                       ...
# 400                 Undoped  Spin-coating | Evaporation | Evaporation
# 401                 Undoped  Spin-coating | Evaporation | Evaporation
# 402                PNDI-2T                 Spin-coating | Evaporation
# 403                 Undoped  Spin-coating | Evaporation | Evaporation
# 404                 Undoped  Spin-coating | Evaporation | Evaporation
#
#     Perovskite_composition_none_stoichiometry_components_in_excess  \
# 0                                       Stoichiometric
# 1                                                 none
# 2                                          PbI2; PbBr2
# 3                                                 PbI2
# 4                                                 none
# ..                                                 ...
# 400                                        PbI2; PbBr2
# 401                                     Stoichiometric
# 402                                     Stoichiometric
# 403                                     Stoichiometric
# 404                                        PbI2; PbBr2
#
#     Perovskite_additives_compounds Perovskite_deposition_procedure  DMF_DMSO  \
# 0                               Mn                    Spin-coating  0.918762
# 1       Phenylethylammonium iodide                    Spin-coating  0.940417
# 2                               Cs                    Spin-coating  0.906358
# 3                          Cl; DPE             Spin-coating >> CBD  0.752266
# 4                              PMA                    Spin-coating  0.979717
# ..                             ...                             ...       ...
# 400                          HATNA                    Spin-coating  0.785070
# 401                        DA2PbI4               Drop-infiltration  0.916023
# 402                       Caffeine                    Spin-coating  0.264875
# 403                   Diiodooctane             Spin-coating >> CBD  0.846651
# 404                             Cs                    Spin-coating  0.382484
#
#     Perovskite_deposition_quenching_media HTL_stack_sequence  \
# 0                           Chlorobenzene               PTAA
# 1                           Diethyl ether               PTAA
# 2                           Diethyl ether               PTAA
# 3                           Chlorobenzene               PTAA
# 4                           Diethyl ether               PTAA
# ..                                    ...                ...
# 400                         Diethyl ether               PTAA
# 401                         Chlorobenzene               PTAA
# 402                         Diethyl ether               PTAA
# 403                         Chlorobenzene               PTAA
# 404                         Diethyl ether               PTAA
#
#     HTL_additives_compounds Backcontact_stack_sequence  \
# 0                      F8BT                       AgAl
# 1                   PolyTPD                       AgAl
# 2                   F4-TCNQ                       AgAl
# 3                       NPB                       AgAl
# 4                      TAPC                       AgAl
# ..                      ...                        ...
# 400                    F8BT                       AgAl
# 401                 PolyTPD                       AgAl
# 402                     NPB                         Al
# 403                    TAPC                       AgAl
# 404                 F4-TCNQ                         Al
#
#      Backcontact_thickness_list  Perovskite_deposition_solvents_IPA  \
# 0                    273.243958                                   0
# 1                    368.981191                                   0
# 2                    224.437778                                   0
# 3                    361.713456                                   0
# 4                    323.890174                                   0
# ..                          ...                                 ...
# 400                   95.335625                                   0
# 401                  131.678064                                   0
# 402                   78.018122                                   0
# 403                  155.053023                                   0
# 404                   94.838063                                   0
#
#     Perovskite_deposition_thermal_annealing      prob
# 0                           60; 80-1.0; 2.0  0.900839
# 1                          65; 100-2.0; 2.0  0.939704
# 2                                180.0-10.0  0.925619
# 3                                80.0-180.0  0.905628
# 4                                   90-30.0  0.940487
# ..                                      ...       ...
# 400                       60; 100-2.0; 10.0  0.939900
# 401                               65.0-20.0  0.939860
# 402                      60; 100-45.0; 50.0  0.938325
# 403                              115.0-30.0  0.922535
# 404                       60; 100-1.0; 10.0  0.908615
#
# [405 rows x 17 columns]

# %%
prob_params_pin = prob_params.sort_values(by='prob',ascending=False).reset_index(drop=True)
prob_params_pin.head(20)
# Out:
#    Cell_architecture Substrate_stack_sequence   ETL_stack_sequence  \
# 0                pin                SLG | ITO  PCBM-60 | C60 | BCP
# 1                pin                SLG | ITO        PCBM-60 | LiF
# 2                pin                SLG | ITO        PCBM-60 | LiF
# 3                pin                SLG | ITO        PCBM-60 | LiF
# 4                pin                SLG | ITO        PCBM-60 | LiF
# 5                pin                SLG | ITO  PCBM-60 | C60 | BCP
# 6                pin                SLG | ITO        PCBM-60 | LiF
# 7                pin                SLG | ITO  PCBM-60 | C60 | BCP
# 8                pin                SLG | ITO  PCBM-60 | C60 | BCP
# 9                pin                SLG | ITO  PCBM-60 | C60 | BCP
# 10               pin                SLG | ITO  PCBM-60 | C60 | BCP
# 11               pin                SLG | ITO  PCBM-60 | C60 | BCP
# 12               pin                SLG | ITO    PCBM-60 | bis-C60
# 13               pin                SLG | ITO        PCBM-60 | LiF
# 14               pin                SLG | ITO              SnO2-np
# 15               pin                SLG | ITO        PCBM-60 | LiF
# 16               pin                SLG | ITO        PCBM-60 | LiF
# 17               pin                SLG | ITO        PCBM-60 | LiF
# 18               pin                SLG | ITO        PCBM-60 | LiF
# 19               pin                SLG | ITO        PCBM-60 | LiF
#
#    ETL_additives_compounds                  ETL_deposition_procedure  \
# 0                  Undoped  Spin-coating | Evaporation | Evaporation
# 1                  Undoped                Spin-coating | Evaporation
# 2                  Undoped                Spin-coating | Evaporation
# 3                  Undoped                Spin-coating | Evaporation
# 4                 PNDI-2T                 Spin-coating | Evaporation
# 5                  Undoped  Spin-coating | Evaporation | Evaporation
# 6                      DIO                Spin-coating | Evaporation
# 7                  Undoped  Spin-coating | Evaporation | Evaporation
# 8                  Undoped  Spin-coating | Evaporation | Evaporation
# 9                  Undoped  Spin-coating | Evaporation | Evaporation
# 10                 Undoped  Spin-coating | Evaporation | Evaporation
# 11                 Undoped  Spin-coating | Evaporation | Evaporation
# 12                 Undoped               Spin-coating | Spin-coating
# 13                 Undoped                Spin-coating | Evaporation
# 14                 Undoped                              Spin-coating
# 15                 Undoped                Spin-coating | Evaporation
# 16                 Undoped                Spin-coating | Evaporation
# 17                 Undoped                Spin-coating | Evaporation
# 18                 Undoped                Spin-coating | Evaporation
# 19                 Undoped                Spin-coating | Evaporation
#
#    Perovskite_composition_none_stoichiometry_components_in_excess  \
# 0                                      Stoichiometric
# 1                                      Stoichiometric
# 2                                      Stoichiometric
# 3                                      Stoichiometric
# 4                                      Stoichiometric
# 5                                      Stoichiometric
# 6                                      Stoichiometric
# 7                                      Stoichiometric
# 8                                         PbI2; PbBr2
# 9                                      Stoichiometric
# 10                                     Stoichiometric
# 11                                     Stoichiometric
# 12                                        PbI2; PbBr2
# 13                                     Stoichiometric
# 14                                     Stoichiometric
# 15                                     Stoichiometric
# 16                                     Stoichiometric
# 17                                     Stoichiometric
# 18                                     Stoichiometric
# 19                                     Stoichiometric
#
#    Perovskite_additives_compounds Perovskite_deposition_procedure  DMF_DMSO  \
# 0                             PMA                    Spin-coating  0.752442
# 1                              Cs                    Spin-coating  0.746834
# 2                             NMA                    Spin-coating  0.752106
# 3                             PMA                    Spin-coating  0.776601
# 4                              MA                    Spin-coating  0.882389
# 5                              Cs                    Spin-coating  0.707541
# 6                              Cs                    Spin-coating  0.826797
# 7                    Diiodooctane             Spin-coating >> CBD  0.748596
# 8                    Diiodooctane                    Spin-coating  0.897588
# 9                          NH4SCN                    Spin-coating  0.822625
# 10                    SP-3D-COF 1                    Spin-coating  0.827428
# 11                             Rb                    Spin-coating  0.776000
# 12                            NMA                    Spin-coating  0.803149
# 13                           ITIC                    Spin-coating  0.795849
# 14                          HATNA                    Spin-coating  0.748760
# 15                            PMA                    Spin-coating  0.873750
# 16                   Diiodooctane                    Spin-coating  0.714765
# 17                  ITIC; PCBM-60                    Spin-coating  0.766008
# 18                      Carbon-nt                    Spin-coating  0.797817
# 19                             Ni                    Spin-coating  0.809163
#
#    Perovskite_deposition_quenching_media HTL_stack_sequence  \
# 0                          Diethyl ether               PTAA
# 1                          Diethyl ether               PTAA
# 2                          Diethyl ether               PTAA
# 3                          Diethyl ether               PTAA
# 4                          Diethyl ether               PTAA
# 5                          Diethyl ether               PTAA
# 6                          Diethyl ether               PTAA
# 7                          Chlorobenzene               PTAA
# 8                          Chlorobenzene               PTAA
# 9                          Chlorobenzene               PTAA
# 10                         Chlorobenzene               PTAA
# 11                         Chlorobenzene               PTAA
# 12                         Diethyl ether               PTAA
# 13                         Chlorobenzene               PTAA
# 14                         Diethyl ether               PTAA
# 15                         Diethyl ether               PTAA
# 16                         Chlorobenzene               PTAA
# 17                         Chlorobenzene               PTAA
# 18                         Chlorobenzene               PTAA
# 19                         Chlorobenzene               PTAA
#
#    HTL_additives_compounds Backcontact_stack_sequence  \
# 0                      NPB                       AgAl
# 1                      NPB                         Al
# 2                     TAPC                       AgAl
# 3                      NPB                         Al
# 4                     TAPC                         Al
# 5                      NPB                         Al
# 6                     TAPC                       AgAl
# 7                      NPB                       AgAl
# 8                     TAPC                       AgAl
# 9                      NPB                       AgAl
# 10                    TAPC                       AgAl
# 11                    TAPC                       AgAl
# 12                     NPB                       AgAl
# 13                    TAPC                       AgAl
# 14                 PolyTPD                       AgAl
# 15                    TAPC                       AgAl
# 16                     NPB                       AgAl
# 17                    TAPC                       AgAl
# 18                     NPB                         Ag
# 19                    TAPC                       AgAl
#
#     Backcontact_thickness_list  Perovskite_deposition_solvents_IPA  \
# 0                    95.520054                                   0
# 1                   103.190626                                   0
# 2                    89.028470                                   0
# 3                    93.374074                                   0
# 4                    79.102843                                   0
# 5                    99.499056                                   0
# 6                    77.244341                                   0
# 7                    95.356217                                   0
# 8                    72.515982                                   0
# 9                    95.545151                                   0
# 10                   83.148544                                   0
# 11                  101.537758                                   0
# 12                  102.904103                                   0
# 13                   95.814635                                   0
# 14                   82.186239                                   0
# 15                  100.924355                                   0
# 16                   91.492722                                   0
# 17                   90.471375                                   0
# 18                   93.631032                                   0
# 19                   83.968500                                   0
#
#    Perovskite_deposition_thermal_annealing      prob
# 0                        60; 100-5.0; 10.0  0.974578
# 1                         60; 100-0.5; 5.0  0.969979
# 2                        60; 100-3.0; 20.0  0.969584
# 3                       60; 100-45.0; 50.0  0.969068
# 4                                   65-2.0  0.966775
# 5                                60.0-45.0  0.965271
# 6                        40; 100-3.0; 10.0  0.963194
# 7                          60; 80-2.0; 5.0  0.961275
# 8                                 130-30.0  0.960297
# 9                       60; 100-10.0; 10.0  0.959266
# 10                        60; 100-0.5; 5.0  0.958950
# 11                        60; 100-1.0; 4.0  0.958848
# 12                      60.0; 100-2.0; 5.0  0.958741
# 13                      60; 105-45.0; 70.0  0.958385
# 14                        60; 80-1.0; 80.0  0.957747
# 15                        65; 100-2.0; 5.0  0.957702
# 16                        60; 80-1.0; 80.0  0.957685
# 17                       60; 100-5.0; 10.0  0.956934
# 18                        60; 100-1.0; 5.0  0.956813
# 19                   60.0; 100.0-5.0; 10.0  0.956413

# %%
prob_params_all = pd.concat([prob_params_nip, prob_params_pin]).sort_values(by='prob',ascending=False).reset_index(drop=True)
prob_params_all.to_csv("prob_params_all.csv",encoding="gbk", index=False)
prob_params_all
# Out:
#     Cell_architecture Substrate_stack_sequence   ETL_stack_sequence  \
# 0                 pin                SLG | ITO  PCBM-60 | C60 | BCP
# 1                 nip                SLG | FTO               TiO2-c
# 2                 pin                SLG | ITO        PCBM-60 | LiF
# 3                 pin                SLG | ITO        PCBM-60 | LiF
# 4                 pin                SLG | ITO        PCBM-60 | LiF
# ..                ...                      ...                  ...
# 684               pin                SLG | ITO  PCBM-60 | C60 | BCP
# 685               pin                SLG | ITO        PCBM-60 | LiF
# 686               nip                SLG | FTO               TiO2-c
# 687               nip                SLG | FTO    TiO2-c | Al2O3-mp
# 688               nip                SLG | FTO               TiO2-c
#
#     ETL_additives_compounds                  ETL_deposition_procedure  \
# 0                   Undoped  Spin-coating | Evaporation | Evaporation
# 1                        Zn                              Spin-coating
# 2                   Undoped                Spin-coating | Evaporation
# 3                   Undoped                Spin-coating | Evaporation
# 4                   Undoped                Spin-coating | Evaporation
# ..                      ...                                       ...
# 684                 Undoped  Spin-coating | Evaporation | Evaporation
# 685                     DIO                Spin-coating | Evaporation
# 686                     HCl                              Spin-coating
# 687                 Undoped                        ALD | Spin-coating
# 688                   TiCl4                              Spin-coating
#
#     Perovskite_composition_none_stoichiometry_components_in_excess  \
# 0                                       Stoichiometric
# 1                                                 PbI2
# 2                                       Stoichiometric
# 3                                       Stoichiometric
# 4                                       Stoichiometric
# ..                                                 ...
# 684                                     Stoichiometric
# 685                                     Stoichiometric
# 686                                               PbI2
# 687                                                 Pb
# 688                                        PbI2; PbBr2
#
#     Perovskite_additives_compounds Perovskite_deposition_procedure  DMF_DMSO  \
# 0                              PMA                    Spin-coating  0.752442
# 1                              PAA                    Spin-coating  0.970659
# 2                               Cs                    Spin-coating  0.746834
# 3                              NMA                    Spin-coating  0.752106
# 4                              PMA                    Spin-coating  0.776601
# ..                             ...                             ...       ...
# 684                             Ni                    Spin-coating  0.773320
# 685                  ITIC; PCBM-60                    Spin-coating  0.979812
# 686                           GuaI                    Spin-coating  0.936893
# 687                           KSCN                    Spin-coating  0.825742
# 688                           SA-2                    Spin-coating  0.923725
#
#     Perovskite_deposition_quenching_media HTL_stack_sequence  \
# 0                           Diethyl ether               PTAA
# 1                           Diethyl ether               PTAA
# 2                           Diethyl ether               PTAA
# 3                           Diethyl ether               PTAA
# 4                           Diethyl ether               PTAA
# ..                                    ...                ...
# 684                         Chlorobenzene               PTAA
# 685                         Chlorobenzene               PTAA
# 686                         Chlorobenzene               PTAA
# 687                         Chlorobenzene               PTAA
# 688                         Chlorobenzene       Spiro-MeOTAD
#
#     HTL_additives_compounds Backcontact_stack_sequence  \
# 0                       NPB                       AgAl
# 1                        O2                       AgAl
# 2                       NPB                         Al
# 3                      TAPC                       AgAl
# 4                       NPB                         Al
# ..                      ...                        ...
# 684                    TAPC                       AgAl
# 685                     NPB                       AgAl
# 686                 F4-TCNQ                       AgAl
# 687                     LAD                         Ag
# 688       JQ3; Li-TFSI; TBP                  MoO3 | Al
#
#      Backcontact_thickness_list  Perovskite_deposition_solvents_IPA  \
# 0                     95.520054                                   0
# 1                    114.374851                                   0
# 2                    103.190626                                   0
# 3                     89.028470                                   0
# 4                     93.374074                                   0
# ..                          ...                                 ...
# 684                   18.695409                                   0
# 685                    0.477438                                   0
# 686                  539.819982                                   0
# 687                  369.358207                                   0
# 688                  451.304151                                   0
#
#     Perovskite_deposition_thermal_annealing      prob
# 0                         60; 100-5.0; 10.0  0.974578
# 1                               100.0-120.0  0.970713
# 2                          60; 100-0.5; 5.0  0.969979
# 3                         60; 100-3.0; 20.0  0.969584
# 4                        60; 100-45.0; 50.0  0.969068
# ..                                      ...       ...
# 684                              180.0-10.0  0.900361
# 685                              110.0-60.0  0.900097
# 686                    65.0; 100.0-1.0; 2.0  0.900092
# 687                              100.0-12.0  0.900054
# 688                               100.0-9.0  0.900041
#
# [689 rows x 17 columns]
